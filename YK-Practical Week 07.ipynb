# %% [markdown]
# ## These exercises will help you with the skills you will need in the assignments
#
# # 0. Text encoding
#
# There is a file called "story-cp1252.txt" you will use in this practical. It has the special open-quote and close-quote characters from code page 1252.
#
# Open it up in two different programs that will render it differently, and take a screenshot of each.
#
# Be creative! Suggestions include Windows Notepad and the more command in a CMD prompt window. On OSX, Microsoft Word (if you specify Windows Latin 1 as the encoding) can render the quotes; most other programs won't.

# %% [markdown]
# *This cell is where you can put the screenshots*

# %% [markdown]
# ### Crasher
#
# The following cell will fail with a unicode exception. Fix it.

# %%
with open('story-cp1252.txt', encoding = 'cp1252') as f:
    f.read()

# %% [markdown]
# ### Copying
#
# Make a copy of story-cp1252.txt in **utf-8 format** and then look at it using some other tool on your computer. (e.g.
# Windows notepad).

# %%
# this is where to put your code
with open('story-cp1252.txt', encoding = 'cp1252') as file1:
    with open('story-utf8.txt', 'w', encoding='utf-8') as file2:
        file2.write(file1.read())

# %% [markdown]
# Make a copy of story-cp1252.txt in **utf-16 format**. Check the size of it in bytes. If you are using Linux or OSX, the UTF-16 file may look like it is corrupted. On Windows it will open normally.

# %%
# this is where to put your code
with open('story-cp1252.txt', encoding = 'cp1252') as file1:
    with open('story-utf8.txt', 'w', encoding='utf-16') as file2:
        file2.write(file1.read())

# %% [markdown]
# # 1. Simple Statistics and NLTK
#
# The following exercises use a portion of the Gutenberg corpus that is stored in the corpus dataset of NLTK. [The Project Gutenberg](http://www.gutenberg.org/) is a large collection of electronic books that are out of copyright. These books are free to download for reading, or for our case, for doing a little of corpus analysis.
#
# To obtain the list of files of NLTK's Gutenberg corpus, type the following commands:

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\ethangodfrey\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\ethangodfrey\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\ethangodfrey\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ethangodfrey\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\ethangodfrey\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\ethangodfrey\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('gutenberg')
nltk.corpus.gutenberg.fileids()
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\EthanGodfrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# To obtain all words in the entire Gutenberg corpus of NLTK, type the following:

# %%
gutenbergwords = nltk.corpus.gutenberg.words()

# %% [markdown]
# Now you can find the total number of words, and the first 10 words (do not attempt to display all the words or your computer will freeze!):

# %%
len(gutenbergwords)
# Out:
# 2621613

# %%
gutenbergwords[:10]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']

# %% [markdown]
# You can also find the words of just a selection of documents, as shown below. For more details of what information you can extract from this corpus, read the "Gutenberg corpus" section of the [NLTK book chapter 2](http://www.nltk.org/book_1ed/ch02.html), section 2.1.

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')
len(emma)
# Out:
# 192427

# %%
emma[:10]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']

# %% [markdown]
# As we have seen in the lectures, we can use Python's `collections.Counter` to find the most frequent words of a document from NLTK's Gutenberg collection. Below you can see how you can find the 5 most frequent words of the word list stored in the variable `emma`:

# %%
import collections
emma_counter = collections.Counter(emma)
print(emma_counter.most_common(5))
# Out:
# [(',', 11454), ('.', 6928), ('to', 5183), ('the', 4844), ('and', 4672)]

# %% [markdown]
# ### Exercise 1.1
# *Write Python code that prints the 10 most frequent words in each of the documents of the Gutenberg corpus. Can you identify any similarities among these list of most frequent words?*

# %%
from collections import Counter
# put your code here
for file_Name in nltk.corpus.gutenberg.fileids():
    print(file_Name)
    words = nltk.corpus.gutenberg.words(file_Name)
    count = Counter(words)
    print(count.most_common(10))
# Out:
# austen-emma.txt
# [(',', 11454), ('.', 6928), ('to', 5183), ('the', 4844), ('and', 4672), ('of', 4279), ('I', 3178), ('a', 3004), ('was', 2385), ('her', 2381)]
# austen-persuasion.txt
# [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
# austen-sense.txt
# [(',', 9397), ('to', 4063), ('.', 3975), ('the', 3861), ('of', 3565), ('and', 3350), ('her', 2436), ('a', 2043), ('I', 2004), ('in', 1904)]
# bible-kjv.txt
# [(',', 70509), ('the', 62103), (':', 43766), ('and', 38847), ('of', 34480), ('.', 26160), ('to', 13396), ('And', 12846), ('that', 12576), ('in', 12331)]
# blake-poems.txt
# [(',', 680), ('the', 351), ('.', 201), ('And', 176), ('and', 169), ('of', 131), ('I', 130), ('in', 116), ('a', 108), ("'", 104)]
# bryant-stories.txt
# [(',', 3481), ('the', 3086), ('and', 1873), ('.', 1817), ('to', 1165), ('a', 988), ('"', 900), ('he', 872), ('of', 801), ('was', 706)]
# burgess-busterbrown.txt
# [('.', 823), (',', 822), ('the', 639), ('he', 562), ('and', 484), ('to', 426), ("'", 401), ('of', 326), ('that', 285), ('a', 275)]
# carroll-alice.txt
# [(',', 1993), ("'", 1731), ('the', 1527), ('and', 802), ('.', 764), ('to', 725), ('a', 615), ('I', 543), ('it', 527), ('she', 509)]
# chesterton-ball.txt
# [(',', 4547), ('the', 4523), ('.', 3589), ('of', 2529), ('and', 2488), ('a', 2184), ('"', 1751), ('to', 1558), ('in', 1355), ('that', 1120)]
# chesterton-brown.txt
# [('the', 4321), (',', 4069), ('.', 2784), ('of', 2087), ('and', 2074), ('a', 2074), ('"', 1461), ('to', 1378), ('in', 1205), ('was', 1141)]
# chesterton-thursday.txt
# [(',', 3488), ('the', 3291), ('.', 2717), ('a', 1713), ('of', 1710), ('and', 1568), ('"', 1336), ('to', 1045), ('in', 888), ('I', 885)]
# edgeworth-parents.txt
# [(',', 15219), ('the', 7149), ('.', 6945), ('to', 5150), ('and', 4769), ('"', 3880), ('of', 3730), ('I', 3656), ("'", 3293), ('a', 3017)]
# melville-moby_dick.txt
# [(',', 18713), ('the', 13721), ('.', 6862), ('of', 6536), ('and', 6024), ('a', 4569), ('to', 4542), (';', 4072), ('in', 3916), ('that', 2982)]
# milton-paradise.txt
# [(',', 10198), ('and', 2799), ('the', 2505), (';', 2317), ('to', 1758), ('of', 1486), ('.', 1254), ('in', 1083), ('his', 986), ('with', 876)]
# shakespeare-caesar.txt
# [(',', 2204), ('.', 1296), ('I', 531), ('the', 502), (':', 499), ('and', 409), ("'", 384), ('to', 370), ('you', 342), ('of', 336)]
# shakespeare-hamlet.txt
# [(',', 2892), ('.', 1886), ('the', 860), ("'", 729), ('and', 606), ('of', 576), ('to', 576), (':', 565), ('I', 553), ('you', 479)]
# shakespeare-macbeth.txt
# [(',', 1962), ('.', 1235), ("'", 637), ('the', 531), (':', 477), ('and', 376), ('I', 333), ('of', 315), ('to', 311), ('?', 241)]
# whitman-leaves.txt
# [(',', 17713), ('the', 8814), ('and', 4797), ('of', 4127), ('I', 2932), ("'", 2362), ('to', 1930), ('-', 1774), ('.', 1769), ('in', 1714)]

# %% [markdown]
# ### Exercise 1.2
# *Find the unique words with length of more than 17 characters in the complete Gutenberg corpus.*
#
# *Hint: to find the distinct items of a Python list you can convert it into a set:*

# %%
my_list = ['a','b','c','a','c']
my_set = set(my_list)
print(my_set)
print(len(my_set))
# Out:
# {'b', 'c', 'a'}
# 3

# %%
# put your code here
words = set([word for word in nltk.corpus.gutenberg.words() if len(word)>17])
print(words)
# Out:
# {'uninterpenetratingly', 'Mahershalalhashbaz', 'characteristically'}

# %% [markdown]
# ### Exercise 1.3
# *Find the words that are longer than 5 characters and occur more than 2000 times in the complete Gutenberg corpus.*

# %%
# put your code here
longer =
# Out:
#   Cell In[20], line 2
#     longer =
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Exercise 1.4
# *Find the average number of words in the documents of the NLTK Gutenberg corpus.*

# %%
# put your code here
num_words = len(nltk.corpus.gutenberg.words())
num_documents = len(nltk.corpus.gutenberg.fileids())
avg = num_words/num_documents
print(avg)
# Out:
# 145645.16666666666

# %% [markdown]
# ### (Optional) Exercise 1.5
# *Find the Gutenberg document that has the longest average word length.*

# %%
# put your code here

# %% [markdown]
# ### Exercise 1.6
# *Find the 10 most frequent bigrams in the entire Gutenberg corpus.*

# %%
# put your code here
words = nltk.corpus.gutenberg.words()
bigrams = nltk.bigrams(words)
bigrams_count = Counter(bigrams)
bigrams_count.most_common(10)
# Out:
# [((',', 'and'), 41294),
#  (('of', 'the'), 18912),
#  (('in', 'the'), 9793),
#  (("'", 's'), 9781),
#  ((';', 'and'), 7559),
#  (('and', 'the'), 6432),
#  (('the', 'LORD'), 5964),
#  ((',', 'the'), 5957),
#  ((',', 'I'), 5677),
#  ((',', 'that'), 5352)]

# %% [markdown]
# ### Exercise 1.7
# *Find the most frequent bigram that begins with "Moby" in Herman Melville's "Moby Dick".*

# %%
# put your code here
[for (w1,w2) in bigrams if w1='Moby']
# Out:
#   Cell In[24], line 2
#     [for (w1,w2) in bigrams if w1='Moby']
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 2. Text Preprocessing with NLTK
# The following exercises will ask questions about tokens, stems, and parts of speech.
#
# ### Exercise 2.1
# *What is the sentence with the largest number of tokens in Austen's "Emma"?*

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\EthanGodfrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# put your code here
from nltk import sent_tokenize, word_tokenize

emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
longest = ''
max = 0

for sentence in sent_tokenize(emma):
    num_words = len(word_tokenize(sentence))
    if num_words > max:
        longest = sentence
        max = num_words

print(longest)
# Out:
# While he lived, it must be only an engagement;
# but she flattered herself, that if divested of the danger of
# drawing her away, it might become an increase of comfort to him.--
# How to do her best by Harriet, was of more difficult decision;--
# how to spare her from any unnecessary pain; how to make
# her any possible atonement; how to appear least her enemy?--
# On these subjects, her perplexity and distress were very great--
# and her mind had to pass again and again through every bitter
# reproach and sorrowful regret that had ever surrounded it.--
# She could only resolve at last, that she would still avoid a
# meeting with her, and communicate all that need be told by letter;
# that it would be inexpressibly desirable to have her removed just
# now for a time from Highbury, and--indulging in one scheme more--
# nearly resolve, that it might be practicable to get an invitation
# for her to Brunswick Square.--Isabella had been pleased with Harriet;
# and a few weeks spent in London must give her some amusement.--
# She did not think it in Harriet's nature to escape being benefited
# by novelty and variety, by the streets, the shops, and the children.--
# At any rate, it would be a proof of attention and kindness in herself,
# from whom every thing was due; a separation for the present; an averting
# of the evil day, when they must all be together again.

# %% [markdown]
# ### Exercise 2.2
# *What are the 5 most frequent parts of speech in Austen's "Emma"? Use the universal tag set*

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\EthanGodfrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\EthanGodfrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\EthanGodfrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
# put your code here
from nltk import pos_tag_sents
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
emma_sent = sent_tokenize(emma)
emma_sent_words =[word_tokenize(sentence) for sentence in emma_sent]

nouns = [
    word_tokenize
]

emma_sent_tagged = pos_tag_sents(emma_sent_words, tagset='universal')
result = emma_sent_tagged.most_common(10) if emma_sent_tagged.tagset == "NOUN" else None
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 7
#       5 emma_sent_words =[word_tokenize(sentence) for sentence in emma_sent]
#       6 emma_sent_tagged = pos_tag_sents(emma_sent_words, tagset='universal')
# ----> 7 result = emma_sent_tagged.most_common(10) if emma_sent_tagged.tagset == "NOUN" else None
#
# AttributeError: 'list' object has no attribute 'tagset'

# %%
emma_sent_tagged
# Out:
# [[('[', 'NOUN'),
#   ('Emma', 'NOUN'),
#   ('by', 'ADP'),
#   ('Jane', 'NOUN'),
#   ('Austen', 'NOUN'),
#   ('1816', 'NUM'),
#   (']', 'NOUN'),
#   ('VOLUME', 'NOUN'),
#   ('I', 'PRON'),
#   ('CHAPTER', 'VERB'),
#   ('I', 'PRON'),
#   ('Emma', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   (',', '.'),
#   ('handsome', 'NOUN'),
#   (',', '.'),
#   ('clever', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('rich', 'ADJ'),
#   (',', '.'),
#   ('with', 'ADP'),
#   ('a', 'DET'),
#   ('comfortable', 'ADJ'),
#   ('home', 'NOUN'),
#   ('and', 'CONJ'),
#   ('happy', 'ADJ'),
#   ('disposition', 'NOUN'),
#   (',', '.'),
#   ('seemed', 'VERB'),
#   ('to', 'PRT'),
#   ('unite', 'VERB'),
#   ('some', 'DET'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('best', 'ADJ'),
#   ('blessings', 'NOUN'),
#   ('of', 'ADP'),
#   ('existence', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('had', 'VERB'),
#   ('lived', 'VERB'),
#   ('nearly', 'ADV'),
#   ('twenty-one', 'NUM'),
#   ('years', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('world', 'NOUN'),
#   ('with', 'ADP'),
#   ('very', 'ADV'),
#   ('little', 'ADJ'),
#   ('to', 'PRT'),
#   ('distress', 'VERB'),
#   ('or', 'CONJ'),
#   ('vex', 'VERB'),
#   ('her', 'PRON'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('was', 'VERB'),
#   ('the', 'DET'),
#   ('youngest', 'ADJ'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('two', 'NUM'),
#   ('daughters', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('most', 'ADV'),
#   ('affectionate', 'ADJ'),
#   (',', '.'),
#   ('indulgent', 'ADJ'),
#   ('father', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('had', 'VERB'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('consequence', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('sister', 'NOUN'),
#   ("'s", 'PRT'),
#   ('marriage', 'NOUN'),
#   (',', '.'),
#   ('been', 'VERB'),
#   ('mistress', 'NOUN'),
#   ('of', 'ADP'),
#   ('his', 'PRON'),
#   ('house', 'NOUN'),
#   ('from', 'ADP'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('early', 'ADJ'),
#   ('period', 'NOUN'),
#   ('.', '.')],
#  [('Her', 'PRON'),
#   ('mother', 'NOUN'),
#   ('had', 'VERB'),
#   ('died', 'VERB'),
#   ('too', 'ADV'),
#   ('long', 'ADV'),
#   ('ago', 'ADV'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('more', 'ADJ'),
#   ('than', 'ADP'),
#   ('an', 'DET'),
#   ('indistinct', 'ADJ'),
#   ('remembrance', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('caresses', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('her', 'PRON'),
#   ('place', 'NOUN'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('supplied', 'VERB'),
#   ('by', 'ADP'),
#   ('an', 'DET'),
#   ('excellent', 'ADJ'),
#   ('woman', 'NOUN'),
#   ('as', 'ADP'),
#   ('governess', 'NOUN'),
#   (',', '.'),
#   ('who', 'PRON'),
#   ('had', 'VERB'),
#   ('fallen', 'VERB'),
#   ('little', 'ADJ'),
#   ('short', 'ADJ'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('mother', 'NOUN'),
#   ('in', 'ADP'),
#   ('affection', 'NOUN'),
#   ('.', '.')],
#  [('Sixteen', 'ADJ'),
#   ('years', 'NOUN'),
#   ('had', 'VERB'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('been', 'VERB'),
#   ('in', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   ("'s", 'PRT'),
#   ('family', 'NOUN'),
#   (',', '.'),
#   ('less', 'CONJ'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('governess', 'NOUN'),
#   ('than', 'ADP'),
#   ('a', 'DET'),
#   ('friend', 'NOUN'),
#   (',', '.'),
#   ('very', 'ADV'),
#   ('fond', 'NOUN'),
#   ('of', 'ADP'),
#   ('both', 'DET'),
#   ('daughters', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('particularly', 'ADV'),
#   ('of', 'ADP'),
#   ('Emma', 'NOUN'),
#   ('.', '.')],
#  [('Between', 'NOUN'),
#   ('_them_', 'VERB'),
#   ('it', 'PRON'),
#   ('was', 'VERB'),
#   ('more', 'ADV'),
#   ('the', 'DET'),
#   ('intimacy', 'NOUN'),
#   ('of', 'ADP'),
#   ('sisters', 'NOUN'),
#   ('.', '.')],
#  [('Even', 'ADV'),
#   ('before', 'ADP'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('had', 'VERB'),
#   ('ceased', 'VERB'),
#   ('to', 'PRT'),
#   ('hold', 'VERB'),
#   ('the', 'DET'),
#   ('nominal', 'ADJ'),
#   ('office', 'NOUN'),
#   ('of', 'ADP'),
#   ('governess', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('mildness', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('temper', 'NOUN'),
#   ('had', 'VERB'),
#   ('hardly', 'ADV'),
#   ('allowed', 'VERB'),
#   ('her', 'PRON'),
#   ('to', 'PRT'),
#   ('impose', 'VERB'),
#   ('any', 'DET'),
#   ('restraint', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('shadow', 'NOUN'),
#   ('of', 'ADP'),
#   ('authority', 'NOUN'),
#   ('being', 'VERB'),
#   ('now', 'ADV'),
#   ('long', 'ADV'),
#   ('passed', 'VERB'),
#   ('away', 'ADV'),
#   (',', '.'),
#   ('they', 'PRON'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('living', 'VERB'),
#   ('together', 'ADV'),
#   ('as', 'ADP'),
#   ('friend', 'NOUN'),
#   ('and', 'CONJ'),
#   ('friend', 'VERB'),
#   ('very', 'ADV'),
#   ('mutually', 'ADV'),
#   ('attached', 'VERB'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('Emma', 'NOUN'),
#   ('doing', 'VERB'),
#   ('just', 'ADV'),
#   ('what', 'PRON'),
#   ('she', 'PRON'),
#   ('liked', 'VERB'),
#   (';', '.'),
#   ('highly', 'ADV'),
#   ('esteeming', 'VERB'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ("'s", 'PRT'),
#   ('judgment', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('directed', 'VERB'),
#   ('chiefly', 'NOUN'),
#   ('by', 'ADP'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('real', 'ADJ'),
#   ('evils', 'NOUN'),
#   (',', '.'),
#   ('indeed', 'ADV'),
#   (',', '.'),
#   ('of', 'ADP'),
#   ('Emma', 'NOUN'),
#   ("'s", 'PRT'),
#   ('situation', 'NOUN'),
#   ('were', 'VERB'),
#   ('the', 'DET'),
#   ('power', 'NOUN'),
#   ('of', 'ADP'),
#   ('having', 'VERB'),
#   ('rather', 'ADV'),
#   ('too', 'ADV'),
#   ('much', 'ADJ'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('way', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('disposition', 'NOUN'),
#   ('to', 'PRT'),
#   ('think', 'VERB'),
#   ('a', 'DET'),
#   ('little', 'ADJ'),
#   ('too', 'ADV'),
#   ('well', 'ADV'),
#   ('of', 'ADP'),
#   ('herself', 'NOUN'),
#   (';', '.'),
#   ('these', 'DET'),
#   ('were', 'VERB'),
#   ('the', 'DET'),
#   ('disadvantages', 'NOUN'),
#   ('which', 'DET'),
#   ('threatened', 'VERB'),
#   ('alloy', 'NOUN'),
#   ('to', 'PRT'),
#   ('her', 'PRON'),
#   ('many', 'ADJ'),
#   ('enjoyments', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('danger', 'NOUN'),
#   (',', '.'),
#   ('however', 'ADV'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('at', 'ADP'),
#   ('present', 'ADJ'),
#   ('so', 'ADV'),
#   ('unperceived', 'ADJ'),
#   (',', '.'),
#   ('that', 'ADP'),
#   ('they', 'PRON'),
#   ('did', 'VERB'),
#   ('not', 'ADV'),
#   ('by', 'ADP'),
#   ('any', 'DET'),
#   ('means', 'NOUN'),
#   ('rank', 'NOUN'),
#   ('as', 'ADP'),
#   ('misfortunes', 'NOUN'),
#   ('with', 'ADP'),
#   ('her', 'PRON'),
#   ('.', '.')],
#  [('Sorrow', 'NOUN'),
#   ('came', 'VERB'),
#   ('--', '.'),
#   ('a', 'DET'),
#   ('gentle', 'ADJ'),
#   ('sorrow', 'NOUN'),
#   ('--', '.'),
#   ('but', 'CONJ'),
#   ('not', 'ADV'),
#   ('at', 'ADP'),
#   ('all', 'DET'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('shape', 'NOUN'),
#   ('of', 'ADP'),
#   ('any', 'DET'),
#   ('disagreeable', 'ADJ'),
#   ('consciousness.', 'NOUN'),
#   ('--', '.'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('married', 'VERB'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('was', 'VERB'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ("'s", 'PRT'),
#   ('loss', 'NOUN'),
#   ('which', 'DET'),
#   ('first', 'ADV'),
#   ('brought', 'VERB'),
#   ('grief', 'NOUN'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('was', 'VERB'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('wedding-day', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('beloved', 'VERB'),
#   ('friend', 'NOUN'),
#   ('that', 'DET'),
#   ('Emma', 'NOUN'),
#   ('first', 'ADV'),
#   ('sat', 'VERB'),
#   ('in', 'ADP'),
#   ('mournful', 'ADJ'),
#   ('thought', 'NOUN'),
#   ('of', 'ADP'),
#   ('any', 'DET'),
#   ('continuance', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('wedding', 'NOUN'),
#   ('over', 'ADP'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('bride-people', 'ADJ'),
#   ('gone', 'VERB'),
#   (',', '.'),
#   ('her', 'PRON'),
#   ('father', 'NOUN'),
#   ('and', 'CONJ'),
#   ('herself', 'PRON'),
#   ('were', 'VERB'),
#   ('left', 'VERB'),
#   ('to', 'PRT'),
#   ('dine', 'VERB'),
#   ('together', 'ADV'),
#   (',', '.'),
#   ('with', 'ADP'),
#   ('no', 'DET'),
#   ('prospect', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('third', 'ADJ'),
#   ('to', 'PRT'),
#   ('cheer', 'VERB'),
#   ('a', 'DET'),
#   ('long', 'ADJ'),
#   ('evening', 'NOUN'),
#   ('.', '.')],
#  [('Her', 'PRON'),
#   ('father', 'NOUN'),
#   ('composed', 'VERB'),
#   ('himself', 'PRON'),
#   ('to', 'PRT'),
#   ('sleep', 'VERB'),
#   ('after', 'ADP'),
#   ('dinner', 'NOUN'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('usual', 'ADJ'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('then', 'ADV'),
#   ('only', 'ADV'),
#   ('to', 'PRT'),
#   ('sit', 'VERB'),
#   ('and', 'CONJ'),
#   ('think', 'VERB'),
#   ('of', 'ADP'),
#   ('what', 'PRON'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('lost', 'VERB'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('event', 'NOUN'),
#   ('had', 'VERB'),
#   ('every', 'DET'),
#   ('promise', 'NOUN'),
#   ('of', 'ADP'),
#   ('happiness', 'NOUN'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('friend', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Weston', 'NOUN'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('man', 'NOUN'),
#   ('of', 'ADP'),
#   ('unexceptionable', 'ADJ'),
#   ('character', 'NOUN'),
#   (',', '.'),
#   ('easy', 'ADJ'),
#   ('fortune', 'NOUN'),
#   (',', '.'),
#   ('suitable', 'ADJ'),
#   ('age', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('pleasant', 'ADJ'),
#   ('manners', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('there', 'DET'),
#   ('was', 'VERB'),
#   ('some', 'DET'),
#   ('satisfaction', 'NOUN'),
#   ('in', 'ADP'),
#   ('considering', 'VERB'),
#   ('with', 'ADP'),
#   ('what', 'PRON'),
#   ('self-denying', 'NOUN'),
#   (',', '.'),
#   ('generous', 'ADJ'),
#   ('friendship', 'NOUN'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('always', 'ADV'),
#   ('wished', 'VERB'),
#   ('and', 'CONJ'),
#   ('promoted', 'VERB'),
#   ('the', 'DET'),
#   ('match', 'NOUN'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('it', 'PRON'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('black', 'ADJ'),
#   ('morning', 'NOUN'),
#   ("'s", 'PRT'),
#   ('work', 'NOUN'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('want', 'NOUN'),
#   ('of', 'ADP'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('would', 'VERB'),
#   ('be', 'VERB'),
#   ('felt', 'VERB'),
#   ('every', 'DET'),
#   ('hour', 'NOUN'),
#   ('of', 'ADP'),
#   ('every', 'DET'),
#   ('day', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('recalled', 'VERB'),
#   ('her', 'PRON'),
#   ('past', 'ADJ'),
#   ('kindness', 'NOUN'),
#   ('--', '.'),
#   ('the', 'DET'),
#   ('kindness', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('affection', 'NOUN'),
#   ('of', 'ADP'),
#   ('sixteen', 'ADJ'),
#   ('years', 'NOUN'),
#   ('--', '.'),
#   ('how', 'ADV'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('taught', 'VERB'),
#   ('and', 'CONJ'),
#   ('how', 'ADV'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('played', 'VERB'),
#   ('with', 'ADP'),
#   ('her', 'PRON'),
#   ('from', 'ADP'),
#   ('five', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   ('--', '.'),
#   ('how', 'ADV'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('devoted', 'VERB'),
#   ('all', 'DET'),
#   ('her', 'PRON'),
#   ('powers', 'NOUN'),
#   ('to', 'PRT'),
#   ('attach', 'VERB'),
#   ('and', 'CONJ'),
#   ('amuse', 'VERB'),
#   ('her', 'PRON'),
#   ('in', 'ADP'),
#   ('health', 'NOUN'),
#   ('--', '.'),
#   ('and', 'CONJ'),
#   ('how', 'ADV'),
#   ('nursed', 'ADJ'),
#   ('her', 'PRON'),
#   ('through', 'ADP'),
#   ('the', 'DET'),
#   ('various', 'ADJ'),
#   ('illnesses', 'NOUN'),
#   ('of', 'ADP'),
#   ('childhood', 'NOUN'),
#   ('.', '.')],
#  [('A', 'DET'),
#   ('large', 'ADJ'),
#   ('debt', 'NOUN'),
#   ('of', 'ADP'),
#   ('gratitude', 'NOUN'),
#   ('was', 'VERB'),
#   ('owing', 'VERB'),
#   ('here', 'ADV'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('the', 'DET'),
#   ('intercourse', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('last', 'ADJ'),
#   ('seven', 'NUM'),
#   ('years', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('equal', 'ADJ'),
#   ('footing', 'NOUN'),
#   ('and', 'CONJ'),
#   ('perfect', 'NOUN'),
#   ('unreserve', 'NOUN'),
#   ('which', 'DET'),
#   ('had', 'VERB'),
#   ('soon', 'ADV'),
#   ('followed', 'VERB'),
#   ('Isabella', 'NOUN'),
#   ("'s", 'PRT'),
#   ('marriage', 'NOUN'),
#   (',', '.'),
#   ('on', 'ADP'),
#   ('their', 'PRON'),
#   ('being', 'VERB'),
#   ('left', 'VERB'),
#   ('to', 'PRT'),
#   ('each', 'DET'),
#   ('other', 'ADJ'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('yet', 'ADV'),
#   ('a', 'DET'),
#   ('dearer', 'NOUN'),
#   (',', '.'),
#   ('tenderer', 'ADJ'),
#   ('recollection', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('a', 'DET'),
#   ('friend', 'NOUN'),
#   ('and', 'CONJ'),
#   ('companion', 'NOUN'),
#   ('such', 'ADJ'),
#   ('as', 'ADP'),
#   ('few', 'ADJ'),
#   ('possessed', 'VERB'),
#   (':', '.'),
#   ('intelligent', 'NOUN'),
#   (',', '.'),
#   ('well-informed', 'ADJ'),
#   (',', '.'),
#   ('useful', 'ADJ'),
#   (',', '.'),
#   ('gentle', 'ADJ'),
#   (',', '.'),
#   ('knowing', 'VERB'),
#   ('all', 'DET'),
#   ('the', 'DET'),
#   ('ways', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('family', 'NOUN'),
#   (',', '.'),
#   ('interested', 'ADJ'),
#   ('in', 'ADP'),
#   ('all', 'DET'),
#   ('its', 'PRON'),
#   ('concerns', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('peculiarly', 'ADV'),
#   ('interested', 'ADJ'),
#   ('in', 'ADP'),
#   ('herself', 'PRON'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('every', 'DET'),
#   ('pleasure', 'NOUN'),
#   (',', '.'),
#   ('every', 'DET'),
#   ('scheme', 'NOUN'),
#   ('of', 'ADP'),
#   ('hers', 'NOUN'),
#   ('--', '.'),
#   ('one', 'NUM'),
#   ('to', 'PRT'),
#   ('whom', 'PRON'),
#   ('she', 'PRON'),
#   ('could', 'VERB'),
#   ('speak', 'VERB'),
#   ('every', 'DET'),
#   ('thought', 'NOUN'),
#   ('as', 'ADP'),
#   ('it', 'PRON'),
#   ('arose', 'VERB'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('who', 'PRON'),
#   ('had', 'VERB'),
#   ('such', 'DET'),
#   ('an', 'DET'),
#   ('affection', 'NOUN'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('as', 'NOUN'),
#   ('could', 'VERB'),
#   ('never', 'ADV'),
#   ('find', 'VERB'),
#   ('fault', 'NOUN'),
#   ('.', '.')],
#  [('How', 'ADV'),
#   ('was', 'VERB'),
#   ('she', 'PRON'),
#   ('to', 'PRT'),
#   ('bear', 'VERB'),
#   ('the', 'DET'),
#   ('change', 'NOUN'),
#   ('?', '.'),
#   ('--', '.'),
#   ('It', 'PRON'),
#   ('was', 'VERB'),
#   ('true', 'ADJ'),
#   ('that', 'ADP'),
#   ('her', 'PRON'),
#   ('friend', 'NOUN'),
#   ('was', 'VERB'),
#   ('going', 'VERB'),
#   ('only', 'ADV'),
#   ('half', 'DET'),
#   ('a', 'DET'),
#   ('mile', 'NOUN'),
#   ('from', 'ADP'),
#   ('them', 'PRON'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('Emma', 'NOUN'),
#   ('was', 'VERB'),
#   ('aware', 'ADJ'),
#   ('that', 'ADP'),
#   ('great', 'ADJ'),
#   ('must', 'VERB'),
#   ('be', 'VERB'),
#   ('the', 'DET'),
#   ('difference', 'NOUN'),
#   ('between', 'ADP'),
#   ('a', 'DET'),
#   ('Mrs.', 'NOUN'),
#   ('Weston', 'NOUN'),
#   (',', '.'),
#   ('only', 'ADV'),
#   ('half', 'DET'),
#   ('a', 'DET'),
#   ('mile', 'NOUN'),
#   ('from', 'ADP'),
#   ('them', 'PRON'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('house', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('with', 'ADP'),
#   ('all', 'DET'),
#   ('her', 'PRON'),
#   ('advantages', 'NOUN'),
#   (',', '.'),
#   ('natural', 'ADJ'),
#   ('and', 'CONJ'),
#   ('domestic', 'ADJ'),
#   (',', '.'),
#   ('she', 'PRON'),
#   ('was', 'VERB'),
#   ('now', 'ADV'),
#   ('in', 'ADP'),
#   ('great', 'ADJ'),
#   ('danger', 'NOUN'),
#   ('of', 'ADP'),
#   ('suffering', 'VERB'),
#   ('from', 'ADP'),
#   ('intellectual', 'ADJ'),
#   ('solitude', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('dearly', 'ADV'),
#   ('loved', 'VERB'),
#   ('her', 'PRON'),
#   ('father', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('he', 'PRON'),
#   ('was', 'VERB'),
#   ('no', 'DET'),
#   ('companion', 'NOUN'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('could', 'VERB'),
#   ('not', 'ADV'),
#   ('meet', 'VERB'),
#   ('her', 'PRON'),
#   ('in', 'ADP'),
#   ('conversation', 'NOUN'),
#   (',', '.'),
#   ('rational', 'ADJ'),
#   ('or', 'CONJ'),
#   ('playful', 'ADJ'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('evil', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('actual', 'ADJ'),
#   ('disparity', 'NOUN'),
#   ('in', 'ADP'),
#   ('their', 'PRON'),
#   ('ages', 'NOUN'),
#   ('(', '.'),
#   ('and', 'CONJ'),
#   ('Mr.', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   ('had', 'VERB'),
#   ('not', 'ADV'),
#   ('married', 'VERB'),
#   ('early', 'ADV'),
#   (')', '.'),
#   ('was', 'VERB'),
#   ('much', 'ADV'),
#   ('increased', 'VERB'),
#   ('by', 'ADP'),
#   ('his', 'PRON'),
#   ('constitution', 'NOUN'),
#   ('and', 'CONJ'),
#   ('habits', 'NOUN'),
#   (';', '.'),
#   ('for', 'ADP'),
#   ('having', 'VERB'),
#   ('been', 'VERB'),
#   ('a', 'DET'),
#   ('valetudinarian', 'ADJ'),
#   ('all', 'DET'),
#   ('his', 'PRON'),
#   ('life', 'NOUN'),
#   (',', '.'),
#   ('without', 'ADP'),
#   ('activity', 'NOUN'),
#   ('of', 'ADP'),
#   ('mind', 'NOUN'),
#   ('or', 'CONJ'),
#   ('body', 'NOUN'),
#   (',', '.'),
#   ('he', 'PRON'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('much', 'ADJ'),
#   ('older', 'ADJ'),
#   ('man', 'NOUN'),
#   ('in', 'ADP'),
#   ('ways', 'NOUN'),
#   ('than', 'ADP'),
#   ('in', 'ADP'),
#   ('years', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('though', 'ADP'),
#   ('everywhere', 'ADV'),
#   ('beloved', 'VERB'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('friendliness', 'NOUN'),
#   ('of', 'ADP'),
#   ('his', 'PRON'),
#   ('heart', 'NOUN'),
#   ('and', 'CONJ'),
#   ('his', 'PRON'),
#   ('amiable', 'ADJ'),
#   ('temper', 'NOUN'),
#   (',', '.'),
#   ('his', 'PRON'),
#   ('talents', 'NOUN'),
#   ('could', 'VERB'),
#   ('not', 'ADV'),
#   ('have', 'VERB'),
#   ('recommended', 'VERB'),
#   ('him', 'PRON'),
#   ('at', 'ADP'),
#   ('any', 'DET'),
#   ('time', 'NOUN'),
#   ('.', '.')],
#  [('Her', 'PRON'),
#   ('sister', 'NOUN'),
#   (',', '.'),
#   ('though', 'ADP'),
#   ('comparatively', 'ADV'),
#   ('but', 'CONJ'),
#   ('little', 'ADJ'),
#   ('removed', 'VERB'),
#   ('by', 'ADP'),
#   ('matrimony', 'NOUN'),
#   (',', '.'),
#   ('being', 'VERB'),
#   ('settled', 'VERB'),
#   ('in', 'ADP'),
#   ('London', 'NOUN'),
#   (',', '.'),
#   ('only', 'ADV'),
#   ('sixteen', 'ADJ'),
#   ('miles', 'NOUN'),
#   ('off', 'ADV'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('much', 'ADJ'),
#   ('beyond', 'ADP'),
#   ('her', 'PRON'),
#   ('daily', 'ADJ'),
#   ('reach', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('many', 'ADJ'),
#   ('a', 'DET'),
#   ('long', 'ADJ'),
#   ('October', 'NOUN'),
#   ('and', 'CONJ'),
#   ('November', 'NOUN'),
#   ('evening', 'NOUN'),
#   ('must', 'VERB'),
#   ('be', 'VERB'),
#   ('struggled', 'VERB'),
#   ('through', 'ADP'),
#   ('at', 'ADP'),
#   ('Hartfield', 'NOUN'),
#   (',', '.'),
#   ('before', 'ADP'),
#   ('Christmas', 'NOUN'),
#   ('brought', 'VERB'),
#   ('the', 'DET'),
#   ('next', 'ADJ'),
#   ('visit', 'NOUN'),
#   ('from', 'ADP'),
#   ('Isabella', 'NOUN'),
#   ('and', 'CONJ'),
#   ('her', 'PRON'),
#   ('husband', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('their', 'PRON'),
#   ('little', 'ADJ'),
#   ('children', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('fill', 'VERB'),
#   ('the', 'DET'),
#   ('house', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('give', 'VERB'),
#   ('her', 'PRON'),
#   ('pleasant', 'ADJ'),
#   ('society', 'NOUN'),
#   ('again', 'ADV'),
#   ('.', '.')],
#  [('Highbury', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('large', 'ADJ'),
#   ('and', 'CONJ'),
#   ('populous', 'ADJ'),
#   ('village', 'NOUN'),
#   (',', '.'),
#   ('almost', 'ADV'),
#   ('amounting', 'VERB'),
#   ('to', 'PRT'),
#   ('a', 'DET'),
#   ('town', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('which', 'DET'),
#   ('Hartfield', 'NOUN'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('spite', 'NOUN'),
#   ('of', 'ADP'),
#   ('its', 'PRON'),
#   ('separate', 'ADJ'),
#   ('lawn', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('shrubberies', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('name', 'NOUN'),
#   (',', '.'),
#   ('did', 'VERB'),
#   ('really', 'ADV'),
#   ('belong', 'ADJ'),
#   (',', '.'),
#   ('afforded', 'VERB'),
#   ('her', 'PRON'),
#   ('no', 'DET'),
#   ('equals', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('Woodhouses', 'NOUN'),
#   ('were', 'VERB'),
#   ('first', 'ADV'),
#   ('in', 'ADP'),
#   ('consequence', 'NOUN'),
#   ('there', 'ADV'),
#   ('.', '.')],
#  [('All', 'DET'),
#   ('looked', 'VERB'),
#   ('up', 'PRT'),
#   ('to', 'PRT'),
#   ('them', 'PRON'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('had', 'VERB'),
#   ('many', 'ADJ'),
#   ('acquaintance', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('place', 'NOUN'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('father', 'NOUN'),
#   ('was', 'VERB'),
#   ('universally', 'ADV'),
#   ('civil', 'ADJ'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('not', 'ADV'),
#   ('one', 'NUM'),
#   ('among', 'ADP'),
#   ('them', 'PRON'),
#   ('who', 'PRON'),
#   ('could', 'VERB'),
#   ('be', 'VERB'),
#   ('accepted', 'VERB'),
#   ('in', 'ADP'),
#   ('lieu', 'NOUN'),
#   ('of', 'ADP'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('for', 'ADP'),
#   ('even', 'ADV'),
#   ('half', 'DET'),
#   ('a', 'DET'),
#   ('day', 'NOUN'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('melancholy', 'ADJ'),
#   ('change', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('Emma', 'NOUN'),
#   ('could', 'VERB'),
#   ('not', 'ADV'),
#   ('but', 'CONJ'),
#   ('sigh', 'ADV'),
#   ('over', 'ADP'),
#   ('it', 'PRON'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('wish', 'VERB'),
#   ('for', 'ADP'),
#   ('impossible', 'ADJ'),
#   ('things', 'NOUN'),
#   (',', '.'),
#   ('till', 'VERB'),
#   ('her', 'PRON'),
#   ('father', 'NOUN'),
#   ('awoke', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('made', 'VERB'),
#   ('it', 'PRON'),
#   ('necessary', 'ADJ'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('cheerful', 'ADJ'),
#   ('.', '.')],
#  [('His', 'PRON'),
#   ('spirits', 'NOUN'),
#   ('required', 'VERB'),
#   ('support', 'NOUN'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('nervous', 'ADJ'),
#   ('man', 'NOUN'),
#   (',', '.'),
#   ('easily', 'ADV'),
#   ('depressed', 'VERB'),
#   (';', '.'),
#   ('fond', 'NOUN'),
#   ('of', 'ADP'),
#   ('every', 'DET'),
#   ('body', 'NOUN'),
#   ('that', 'ADP'),
#   ('he', 'PRON'),
#   ('was', 'VERB'),
#   ('used', 'VERB'),
#   ('to', 'PRT'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('hating', 'VERB'),
#   ('to', 'PRT'),
#   ('part', 'NOUN'),
#   ('with', 'ADP'),
#   ('them', 'PRON'),
#   (';', '.'),
#   ('hating', 'VERB'),
#   ('change', 'NOUN'),
#   ('of', 'ADP'),
#   ('every', 'DET'),
#   ('kind', 'NOUN'),
#   ('.', '.')],
#  [('Matrimony', 'NOUN'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('the', 'DET'),
#   ('origin', 'NOUN'),
#   ('of', 'ADP'),
#   ('change', 'NOUN'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('always', 'ADV'),
#   ('disagreeable', 'ADJ'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('he', 'PRON'),
#   ('was', 'VERB'),
#   ('by', 'ADP'),
#   ('no', 'DET'),
#   ('means', 'NOUN'),
#   ('yet', 'ADV'),
#   ('reconciled', 'VERB'),
#   ('to', 'PRT'),
#   ('his', 'PRON'),
#   ('own', 'ADJ'),
#   ('daughter', 'NOUN'),
#   ("'s", 'PRT'),
#   ('marrying', 'NOUN'),
#   (',', '.'),
#   ('nor', 'CONJ'),
#   ('could', 'VERB'),
#   ('ever', 'ADV'),
#   ('speak', 'VERB'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('but', 'CONJ'),
#   ('with', 'ADP'),
#   ('compassion', 'NOUN'),
#   (',', '.'),
#   ('though', 'ADP'),
#   ('it', 'PRON'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('entirely', 'ADV'),
#   ('a', 'DET'),
#   ('match', 'NOUN'),
#   ('of', 'ADP'),
#   ('affection', 'NOUN'),
#   (',', '.'),
#   ('when', 'ADV'),
#   ('he', 'PRON'),
#   ('was', 'VERB'),
#   ('now', 'ADV'),
#   ('obliged', 'VERB'),
#   ('to', 'PRT'),
#   ('part', 'NOUN'),
#   ('with', 'ADP'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('too', 'ADV'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('from', 'ADP'),
#   ('his', 'PRON'),
#   ('habits', 'NOUN'),
#   ('of', 'ADP'),
#   ('gentle', 'ADJ'),
#   ('selfishness', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('of', 'ADP'),
#   ('being', 'VERB'),
#   ('never', 'ADV'),
#   ('able', 'ADJ'),
#   ('to', 'PRT'),
#   ('suppose', 'VERB'),
#   ('that', 'ADP'),
#   ('other', 'ADJ'),
#   ('people', 'NOUN'),
#   ('could', 'VERB'),
#   ('feel', 'VERB'),
#   ('differently', 'ADV'),
#   ('from', 'ADP'),
#   ('himself', 'PRON'),
#   (',', '.'),
#   ('he', 'PRON'),
#   ('was', 'VERB'),
#   ('very', 'ADV'),
#   ('much', 'ADV'),
#   ('disposed', 'VERB'),
#   ('to', 'PRT'),
#   ('think', 'VERB'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('had', 'VERB'),
#   ('done', 'VERB'),
#   ('as', 'ADP'),
#   ('sad', 'NOUN'),
#   ('a', 'DET'),
#   ('thing', 'NOUN'),
#   ('for', 'ADP'),
#   ('herself', 'NOUN'),
#   ('as', 'ADP'),
#   ('for', 'ADP'),
#   ('them', 'PRON'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('would', 'VERB'),
#   ('have', 'VERB'),
#   ('been', 'VERB'),
#   ('a', 'DET'),
#   ('great', 'ADJ'),
#   ('deal', 'NOUN'),
#   ('happier', 'NOUN'),
#   ('if', 'ADP'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('spent', 'VERB'),
#   ('all', 'DET'),
#   ('the', 'DET'),
#   ('rest', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('life', 'NOUN'),
#   ('at', 'ADP'),
#   ('Hartfield', 'NOUN'),
#   ('.', '.')],
#  [('Emma', 'NOUN'),
#   ('smiled', 'VERB'),
#   ('and', 'CONJ'),
#   ('chatted', 'VERB'),
#   ('as', 'ADV'),
#   ('cheerfully', 'ADV'),
#   ('as', 'ADP'),
#   ('she', 'PRON'),
#   ('could', 'VERB'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('keep', 'VERB'),
#   ('him', 'PRON'),
#   ('from', 'ADP'),
#   ('such', 'ADJ'),
#   ('thoughts', 'NOUN'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('when', 'ADV'),
#   ('tea', 'NOUN'),
#   ('came', 'VERB'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('was', 'VERB'),
#   ('impossible', 'ADJ'),
#   ('for', 'ADP'),
#   ('him', 'PRON'),
#   ('not', 'ADV'),
#   ('to', 'PRT'),
#   ('say', 'VERB'),
#   ('exactly', 'ADV'),
#   ('as', 'ADP'),
#   ('he', 'PRON'),
#   ('had', 'VERB'),
#   ('said', 'VERB'),
#   ('at', 'ADP'),
#   ('dinner', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('Poor', 'NOUN'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('!', '.'),
#   ('--', '.'),
#   ('I', 'PRON'),
#   ('wish', 'VERB'),
#   ('she', 'PRON'),
#   ('were', 'VERB'),
#   ('here', 'ADV'),
#   ('again', 'ADV'),
#   ('.', '.')],
#  [('What', 'PRON'),
#   ('a', 'DET'),
#   ('pity', 'NOUN'),
#   ('it', 'PRON'),
#   ('is', 'VERB'),
#   ('that', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Weston', 'NOUN'),
#   ('ever', 'ADV'),
#   ('thought', 'VERB'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('!', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('I', 'PRON'),
#   ('can', 'VERB'),
#   ('not', 'ADV'),
#   ('agree', 'VERB'),
#   ('with', 'ADP'),
#   ('you', 'PRON'),
#   (',', '.'),
#   ('papa', 'VERB'),
#   (';', '.'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   ('I', 'PRON'),
#   ('can', 'VERB'),
#   ('not', 'ADV'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Weston', 'NOUN'),
#   ('is', 'VERB'),
#   ('such', 'ADJ'),
#   ('a', 'DET'),
#   ('good-humoured', 'ADJ'),
#   (',', '.'),
#   ('pleasant', 'ADJ'),
#   (',', '.'),
#   ('excellent', 'ADJ'),
#   ('man', 'NOUN'),
#   (',', '.'),
#   ('that', 'ADP'),
#   ('he', 'PRON'),
#   ('thoroughly', 'VERB'),
#   ('deserves', 'VERB'),
#   ('a', 'DET'),
#   ('good', 'ADJ'),
#   ('wife', 'NOUN'),
#   (';', '.'),
#   ('--', '.'),
#   ('and', 'CONJ'),
#   ('you', 'PRON'),
#   ('would', 'VERB'),
#   ('not', 'ADV'),
#   ('have', 'VERB'),
#   ('had', 'VERB'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('live', 'VERB'),
#   ('with', 'ADP'),
#   ('us', 'PRON'),
#   ('for', 'ADP'),
#   ('ever', 'ADV'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('bear', 'ADP'),
#   ('all', 'DET'),
#   ('my', 'PRON'),
#   ('odd', 'ADJ'),
#   ('humours', 'NOUN'),
#   (',', '.'),
#   ('when', 'ADV'),
#   ('she', 'PRON'),
#   ('might', 'VERB'),
#   ('have', 'VERB'),
#   ('a', 'DET'),
#   ('house', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('?', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('A', 'DET'),
#   ('house', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('!', '.'),
#   ('--', '.'),
#   ('But', 'CONJ'),
#   ('where', 'ADV'),
#   ('is', 'VERB'),
#   ('the', 'DET'),
#   ('advantage', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('house', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('?', '.')],
#  [('This', 'DET'),
#   ('is', 'VERB'),
#   ('three', 'NUM'),
#   ('times', 'NOUN'),
#   ('as', 'ADP'),
#   ('large.', 'NOUN'),
#   ('--', '.'),
#   ('And', 'CONJ'),
#   ('you', 'PRON'),
#   ('have', 'VERB'),
#   ('never', 'ADV'),
#   ('any', 'DET'),
#   ('odd', 'ADJ'),
#   ('humours', 'NOUN'),
#   (',', '.'),
#   ('my', 'PRON'),
#   ('dear', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('How', 'ADV'),
#   ('often', 'ADV'),
#   ('we', 'PRON'),
#   ('shall', 'VERB'),
#   ('be', 'VERB'),
#   ('going', 'VERB'),
#   ('to', 'PRT'),
#   ('see', 'VERB'),
#   ('them', 'PRON'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('they', 'PRON'),
#   ('coming', 'VERB'),
#   ('to', 'PRT'),
#   ('see', 'VERB'),
#   ('us', 'PRON'),
#   ('!', '.'),
#   ('--', '.'),
#   ('We', 'PRON'),
#   ('shall', 'VERB'),
#   ('be', 'VERB'),
#   ('always', 'ADV'),
#   ('meeting', 'NOUN'),
#   ('!', '.')],
#  [('_We_', 'NOUN'),
#   ('must', 'VERB'),
#   ('begin', 'VERB'),
#   (';', '.'),
#   ('we', 'PRON'),
#   ('must', 'VERB'),
#   ('go', 'VERB'),
#   ('and', 'CONJ'),
#   ('pay', 'VERB'),
#   ('wedding', 'VERB'),
#   ('visit', 'NOUN'),
#   ('very', 'ADV'),
#   ('soon', 'ADV'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('My', 'PRON'),
#   ('dear', 'NOUN'),
#   (',', '.'),
#   ('how', 'ADV'),
#   ('am', 'VERB'),
#   ('I', 'PRON'),
#   ('to', 'PRT'),
#   ('get', 'VERB'),
#   ('so', 'ADV'),
#   ('far', 'ADV'),
#   ('?', '.')],
#  [('Randalls', 'NOUN'),
#   ('is', 'VERB'),
#   ('such', 'ADJ'),
#   ('a', 'DET'),
#   ('distance', 'NOUN'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('could', 'VERB'),
#   ('not', 'ADV'),
#   ('walk', 'VERB'),
#   ('half', 'NOUN'),
#   ('so', 'ADV'),
#   ('far', 'ADV'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('No', 'DET'),
#   (',', '.'),
#   ('papa', 'NOUN'),
#   (',', '.'),
#   ('nobody', 'NOUN'),
#   ('thought', 'NOUN'),
#   ('of', 'ADP'),
#   ('your', 'PRON'),
#   ('walking', 'NOUN'),
#   ('.', '.')],
#  [('We', 'PRON'),
#   ('must', 'VERB'),
#   ('go', 'VERB'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('carriage', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('sure', 'ADJ'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'), ('The', 'DET'), ('carriage', 'NOUN'), ('!', '.')],
#  [('But', 'CONJ'),
#   ('James', 'NOUN'),
#   ('will', 'VERB'),
#   ('not', 'ADV'),
#   ('like', 'VERB'),
#   ('to', 'PRT'),
#   ('put', 'VERB'),
#   ('the', 'DET'),
#   ('horses', 'NOUN'),
#   ('to', 'PRT'),
#   ('for', 'ADP'),
#   ('such', 'DET'),
#   ('a', 'DET'),
#   ('little', 'ADJ'),
#   ('way', 'NOUN'),
#   (';', '.'),
#   ('--', '.'),
#   ('and', 'CONJ'),
#   ('where', 'ADV'),
#   ('are', 'VERB'),
#   ('the', 'DET'),
#   ('poor', 'ADJ'),
#   ('horses', 'NOUN'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('while', 'ADP'),
#   ('we', 'PRON'),
#   ('are', 'VERB'),
#   ('paying', 'VERB'),
#   ('our', 'PRON'),
#   ('visit', 'NOUN'),
#   ('?', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('They', 'PRON'),
#   ('are', 'VERB'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('put', 'VERB'),
#   ('into', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Weston', 'NOUN'),
#   ("'s", 'PRT'),
#   ('stable', 'ADJ'),
#   (',', '.'),
#   ('papa', 'NOUN'),
#   ('.', '.')],
#  [('You', 'PRON'),
#   ('know', 'VERB'),
#   ('we', 'PRON'),
#   ('have', 'VERB'),
#   ('settled', 'VERB'),
#   ('all', 'DET'),
#   ('that', 'DET'),
#   ('already', 'ADV'),
#   ('.', '.')],
#  [('We', 'PRON'),
#   ('talked', 'VERB'),
#   ('it', 'PRON'),
#   ('all', 'DET'),
#   ('over', 'ADP'),
#   ('with', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Weston', 'NOUN'),
#   ('last', 'ADJ'),
#   ('night', 'NOUN'),
#   ('.', '.')],
#  [('And', 'CONJ'),
#   ('as', 'ADP'),
#   ('for', 'ADP'),
#   ('James', 'NOUN'),
#   (',', '.'),
#   ('you', 'PRON'),
#   ('may', 'VERB'),
#   ('be', 'VERB'),
#   ('very', 'ADV'),
#   ('sure', 'ADJ'),
#   ('he', 'PRON'),
#   ('will', 'VERB'),
#   ('always', 'ADV'),
#   ('like', 'VERB'),
#   ('going', 'VERB'),
#   ('to', 'PRT'),
#   ('Randalls', 'NOUN'),
#   (',', '.'),
#   ('because', 'ADP'),
#   ('of', 'ADP'),
#   ('his', 'PRON'),
#   ('daughter', 'NOUN'),
#   ("'s", 'PRT'),
#   ('being', 'VERB'),
#   ('housemaid', 'VERB'),
#   ('there', 'ADV'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('only', 'ADV'),
#   ('doubt', 'VERB'),
#   ('whether', 'ADP'),
#   ('he', 'PRON'),
#   ('will', 'VERB'),
#   ('ever', 'ADV'),
#   ('take', 'VERB'),
#   ('us', 'PRON'),
#   ('anywhere', 'ADV'),
#   ('else', 'ADV'),
#   ('.', '.')],
#  [('That', 'DET'),
#   ('was', 'VERB'),
#   ('your', 'PRON'),
#   ('doing', 'VERB'),
#   (',', '.'),
#   ('papa', 'NOUN'),
#   ('.', '.')],
#  [('You', 'PRON'),
#   ('got', 'VERB'),
#   ('Hannah', 'NOUN'),
#   ('that', 'ADP'),
#   ('good', 'ADJ'),
#   ('place', 'NOUN'),
#   ('.', '.')],
#  [('Nobody', 'NOUN'),
#   ('thought', 'NOUN'),
#   ('of', 'ADP'),
#   ('Hannah', 'NOUN'),
#   ('till', 'NOUN'),
#   ('you', 'PRON'),
#   ('mentioned', 'VERB'),
#   ('her', 'PRON'),
#   ('--', '.'),
#   ('James', 'NOUN'),
#   ('is', 'VERB'),
#   ('so', 'ADV'),
#   ('obliged', 'ADJ'),
#   ('to', 'PRT'),
#   ('you', 'PRON'),
#   ('!', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('I', 'PRON'),
#   ('am', 'VERB'),
#   ('very', 'ADV'),
#   ('glad', 'ADJ'),
#   ('I', 'PRON'),
#   ('did', 'VERB'),
#   ('think', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('was', 'VERB'),
#   ('very', 'ADV'),
#   ('lucky', 'ADJ'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('I', 'PRON'),
#   ('would', 'VERB'),
#   ('not', 'ADV'),
#   ('have', 'VERB'),
#   ('had', 'VERB'),
#   ('poor', 'ADJ'),
#   ('James', 'NOUN'),
#   ('think', 'VERB'),
#   ('himself', 'PRON'),
#   ('slighted', 'VERB'),
#   ('upon', 'ADP'),
#   ('any', 'DET'),
#   ('account', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('I', 'PRON'),
#   ('am', 'VERB'),
#   ('sure', 'ADJ'),
#   ('she', 'PRON'),
#   ('will', 'VERB'),
#   ('make', 'VERB'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('good', 'ADJ'),
#   ('servant', 'NOUN'),
#   (':', '.'),
#   ('she', 'PRON'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('civil', 'ADJ'),
#   (',', '.'),
#   ('pretty-spoken', 'ADJ'),
#   ('girl', 'NOUN'),
#   (';', '.'),
#   ('I', 'PRON'),
#   ('have', 'VERB'),
#   ('a', 'DET'),
#   ('great', 'ADJ'),
#   ('opinion', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('.', '.')],
#  [('Whenever', 'ADV'),
#   ('I', 'PRON'),
#   ('see', 'VERB'),
#   ('her', 'PRON'),
#   (',', '.'),
#   ('she', 'PRON'),
#   ('always', 'ADV'),
#   ('curtseys', 'NOUN'),
#   ('and', 'CONJ'),
#   ('asks', 'NOUN'),
#   ('me', 'PRON'),
#   ('how', 'ADV'),
#   ('I', 'PRON'),
#   ('do', 'VERB'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('pretty', 'ADJ'),
#   ('manner', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('when', 'ADV'),
#   ('you', 'PRON'),
#   ('have', 'VERB'),
#   ('had', 'VERB'),
#   ('her', 'PRON'),
#   ('here', 'ADV'),
#   ('to', 'PRT'),
#   ('do', 'VERB'),
#   ('needlework', 'ADV'),
#   (',', '.'),
#   ('I', 'PRON'),
#   ('observe', 'VERB'),
#   ('she', 'PRON'),
#   ('always', 'ADV'),
#   ('turns', 'VERB'),
#   ('the', 'DET'),
#   ('lock', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('door', 'NOUN'),
#   ('the', 'DET'),
#   ('right', 'ADJ'),
#   ('way', 'NOUN'),
#   ('and', 'CONJ'),
#   ('never', 'ADV'),
#   ('bangs', 'NOUN'),
#   ('it', 'PRON'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('am', 'VERB'),
#   ('sure', 'ADJ'),
#   ('she', 'PRON'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('an', 'DET'),
#   ('excellent', 'ADJ'),
#   ('servant', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('it', 'PRON'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('a', 'DET'),
#   ('great', 'ADJ'),
#   ('comfort', 'NOUN'),
#   ('to', 'PRT'),
#   ('poor', 'ADJ'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('somebody', 'NOUN'),
#   ('about', 'ADP'),
#   ('her', 'PRON'),
#   ('that', 'ADP'),
#   ('she', 'PRON'),
#   ('is', 'VERB'),
#   ('used', 'VERB'),
#   ('to', 'PRT'),
#   ('see', 'VERB'),
#   ('.', '.')],
#  [('Whenever', 'ADV'),
#   ('James', 'NOUN'),
#   ('goes', 'VERB'),
#   ('over', 'ADP'),
#   ('to', 'PRT'),
#   ('see', 'VERB'),
#   ('his', 'PRON'),
#   ('daughter', 'NOUN'),
#   (',', '.'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   (',', '.'),
#   ('she', 'PRON'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('hearing', 'NOUN'),
#   ('of', 'ADP'),
#   ('us', 'PRON'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('able', 'ADJ'),
#   ('to', 'PRT'),
#   ('tell', 'VERB'),
#   ('her', 'PRON'),
#   ('how', 'ADV'),
#   ('we', 'PRON'),
#   ('all', 'DET'),
#   ('are', 'VERB'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Emma', 'NOUN'),
#   ('spared', 'VERB'),
#   ('no', 'DET'),
#   ('exertions', 'NOUN'),
#   ('to', 'PRT'),
#   ('maintain', 'VERB'),
#   ('this', 'DET'),
#   ('happier', 'ADJ'),
#   ('flow', 'NOUN'),
#   ('of', 'ADP'),
#   ('ideas', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('hoped', 'VERB'),
#   (',', '.'),
#   ('by', 'ADP'),
#   ('the', 'DET'),
#   ('help', 'NOUN'),
#   ('of', 'ADP'),
#   ('backgammon', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('get', 'VERB'),
#   ('her', 'PRON'),
#   ('father', 'NOUN'),
#   ('tolerably', 'ADV'),
#   ('through', 'ADP'),
#   ('the', 'DET'),
#   ('evening', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('be', 'VERB'),
#   ('attacked', 'VERB'),
#   ('by', 'ADP'),
#   ('no', 'DET'),
#   ('regrets', 'NOUN'),
#   ('but', 'CONJ'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('backgammon-table', 'ADJ'),
#   ('was', 'VERB'),
#   ('placed', 'VERB'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('a', 'DET'),
#   ('visitor', 'NOUN'),
#   ('immediately', 'ADV'),
#   ('afterwards', 'NOUN'),
#   ('walked', 'VERB'),
#   ('in', 'ADP'),
#   ('and', 'CONJ'),
#   ('made', 'VERB'),
#   ('it', 'PRON'),
#   ('unnecessary', 'ADJ'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Knightley', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('sensible', 'ADJ'),
#   ('man', 'NOUN'),
#   ('about', 'ADP'),
#   ('seven', 'NUM'),
#   ('or', 'CONJ'),
#   ('eight-and-thirty', 'ADJ'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('not', 'ADV'),
#   ('only', 'ADV'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('old', 'ADJ'),
#   ('and', 'CONJ'),
#   ('intimate', 'ADJ'),
#   ('friend', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('family', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('particularly', 'ADV'),
#   ('connected', 'VERB'),
#   ('with', 'ADP'),
#   ('it', 'PRON'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('the', 'DET'),
#   ('elder', 'NOUN'),
#   ('brother', 'NOUN'),
#   ('of', 'ADP'),
#   ('Isabella', 'NOUN'),
#   ("'s", 'PRT'),
#   ('husband', 'NOUN'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('lived', 'VERB'),
#   ('about', 'ADP'),
#   ('a', 'DET'),
#   ('mile', 'NOUN'),
#   ('from', 'ADP'),
#   ('Highbury', 'NOUN'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('frequent', 'ADJ'),
#   ('visitor', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('always', 'ADV'),
#   ('welcome', 'VERB'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('at', 'ADP'),
#   ('this', 'DET'),
#   ('time', 'NOUN'),
#   ('more', 'ADV'),
#   ('welcome', 'ADJ'),
#   ('than', 'ADP'),
#   ('usual', 'ADJ'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('coming', 'VERB'),
#   ('directly', 'ADV'),
#   ('from', 'ADP'),
#   ('their', 'PRON'),
#   ('mutual', 'ADJ'),
#   ('connexions', 'NOUN'),
#   ('in', 'ADP'),
#   ('London', 'NOUN'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('had', 'VERB'),
#   ('returned', 'VERB'),
#   ('to', 'PRT'),
#   ('a', 'DET'),
#   ('late', 'ADJ'),
#   ('dinner', 'NOUN'),
#   (',', '.'),
#   ('after', 'ADP'),
#   ('some', 'DET'),
#   ('days', 'NOUN'),
#   ("'", 'PRT'),
#   ('absence', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('now', 'ADV'),
#   ('walked', 'VERB'),
#   ('up', 'PRT'),
#   ('to', 'PRT'),
#   ('Hartfield', 'NOUN'),
#   ('to', 'PRT'),
#   ('say', 'VERB'),
#   ('that', 'ADP'),
#   ('all', 'DET'),
#   ('were', 'VERB'),
#   ('well', 'ADV'),
#   ('in', 'ADP'),
#   ('Brunswick', 'NOUN'),
#   ('Square', 'NOUN'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('was', 'VERB'),
#   ('a', 'DET'),
#   ('happy', 'ADJ'),
#   ('circumstance', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('animated', 'VERB'),
#   ('Mr.', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   ('for', 'ADP'),
#   ('some', 'DET'),
#   ('time', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Knightley', 'NOUN'),
#   ('had', 'VERB'),
#   ('a', 'DET'),
#   ('cheerful', 'ADJ'),
#   ('manner', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('always', 'ADV'),
#   ('did', 'VERB'),
#   ('him', 'PRON'),
#   ('good', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('his', 'PRON'),
#   ('many', 'ADJ'),
#   ('inquiries', 'NOUN'),
#   ('after', 'ADP'),
#   ('``', '.'),
#   ('poor', 'ADJ'),
#   ('Isabella', 'NOUN'),
#   ("''", '.'),
#   ('and', 'CONJ'),
#   ('her', 'PRON'),
#   ('children', 'NOUN'),
#   ('were', 'VERB'),
#   ('answered', 'VERB'),
#   ('most', 'ADJ'),
#   ('satisfactorily', 'ADV'),
#   ('.', '.')],
#  [('When', 'ADV'),
#   ('this', 'DET'),
#   ('was', 'VERB'),
#   ('over', 'ADV'),
#   (',', '.'),
#   ('Mr.', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   ('gratefully', 'ADV'),
#   ('observed', 'VERB'),
#   (',', '.'),
#   ('``', '.'),
#   ('It', 'PRON'),
#   ('is', 'VERB'),
#   ('very', 'ADV'),
#   ('kind', 'NOUN'),
#   ('of', 'ADP'),
#   ('you', 'PRON'),
#   (',', '.'),
#   ('Mr.', 'NOUN'),
#   ('Knightley', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('come', 'VERB'),
#   ('out', 'PRT'),
#   ('at', 'ADP'),
#   ('this', 'DET'),
#   ('late', 'ADJ'),
#   ('hour', 'NOUN'),
#   ('to', 'PRT'),
#   ('call', 'VERB'),
#   ('upon', 'ADP'),
#   ('us', 'PRON'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('am', 'VERB'),
#   ('afraid', 'ADJ'),
#   ('you', 'PRON'),
#   ('must', 'VERB'),
#   ('have', 'VERB'),
#   ('had', 'VERB'),
#   ('a', 'DET'),
#   ('shocking', 'NOUN'),
#   ('walk', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('Not', 'ADV'),
#   ('at', 'ADP'),
#   ('all', 'DET'),
#   (',', '.'),
#   ('sir', 'NOUN'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('beautiful', 'ADJ'),
#   ('moonlight', 'NOUN'),
#   ('night', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('so', 'ADV'),
#   ('mild', 'ADJ'),
#   ('that', 'ADP'),
#   ('I', 'PRON'),
#   ('must', 'VERB'),
#   ('draw', 'VERB'),
#   ('back', 'ADV'),
#   ('from', 'ADP'),
#   ('your', 'PRON'),
#   ('great', 'ADJ'),
#   ('fire', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('But', 'CONJ'),
#   ('you', 'PRON'),
#   ('must', 'VERB'),
#   ('have', 'VERB'),
#   ('found', 'VERB'),
#   ('it', 'PRON'),
#   ('very', 'ADV'),
#   ('damp', 'ADJ'),
#   ('and', 'CONJ'),
#   ('dirty', 'NOUN'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('wish', 'VERB'),
#   ('you', 'PRON'),
#   ('may', 'VERB'),
#   ('not', 'ADV'),
#   ('catch', 'VERB'),
#   ('cold', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'), ('Dirty', 'NOUN'), (',', '.'), ('sir', 'NOUN'), ('!', '.')],
#  [('Look', 'NOUN'),
#   ('at', 'ADP'),
#   ('my', 'PRON'),
#   ('shoes', 'NOUN'),
#   ('.', '.')],
#  [('Not', 'ADV'),
#   ('a', 'DET'),
#   ('speck', 'NOUN'),
#   ('on', 'ADP'),
#   ('them', 'PRON'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'), ('Well', 'ADV'), ('!', '.')],
#  [('that', 'DET'),
#   ('is', 'VERB'),
#   ('quite', 'ADV'),
#   ('surprising', 'ADJ'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('we', 'PRON'),
#   ('have', 'VERB'),
#   ('had', 'VERB'),
#   ('a', 'DET'),
#   ('vast', 'ADJ'),
#   ('deal', 'NOUN'),
#   ('of', 'ADP'),
#   ('rain', 'NOUN'),
#   ('here', 'ADV'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('rained', 'VERB'),
#   ('dreadfully', 'ADV'),
#   ('hard', 'ADJ'),
#   ('for', 'ADP'),
#   ('half', 'DET'),
#   ('an', 'DET'),
#   ('hour', 'NOUN'),
#   ('while', 'ADP'),
#   ('we', 'PRON'),
#   ('were', 'VERB'),
#   ('at', 'ADP'),
#   ('breakfast', 'NOUN'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('wanted', 'VERB'),
#   ('them', 'PRON'),
#   ('to', 'PRT'),
#   ('put', 'VERB'),
#   ('off', 'PRT'),
#   ('the', 'DET'),
#   ('wedding', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('By', 'ADP'),
#   ('the', 'DET'),
#   ('bye', 'NOUN'),
#   ('--', '.'),
#   ('I', 'PRON'),
#   ('have', 'VERB'),
#   ('not', 'ADV'),
#   ('wished', 'VERB'),
#   ('you', 'PRON'),
#   ('joy', 'VERB'),
#   ('.', '.')],
#  [('Being', 'VERB'),
#   ('pretty', 'ADV'),
#   ('well', 'ADV'),
#   ('aware', 'ADJ'),
#   ('of', 'ADP'),
#   ('what', 'PRON'),
#   ('sort', 'NOUN'),
#   ('of', 'ADP'),
#   ('joy', 'NOUN'),
#   ('you', 'PRON'),
#   ('must', 'VERB'),
#   ('both', 'DET'),
#   ('be', 'VERB'),
#   ('feeling', 'NOUN'),
#   (',', '.'),
#   ('I', 'PRON'),
#   ('have', 'VERB'),
#   ('been', 'VERB'),
#   ('in', 'ADP'),
#   ('no', 'DET'),
#   ('hurry', 'NOUN'),
#   ('with', 'ADP'),
#   ('my', 'PRON'),
#   ('congratulations', 'NOUN'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('I', 'PRON'),
#   ('hope', 'VERB'),
#   ('it', 'PRON'),
#   ('all', 'DET'),
#   ('went', 'VERB'),
#   ('off', 'PRT'),
#   ('tolerably', 'ADV'),
#   ('well', 'ADV'),
#   ('.', '.')],
#  [('How', 'ADV'),
#   ('did', 'VERB'),
#   ('you', 'PRON'),
#   ('all', 'DET'),
#   ('behave', 'VERB'),
#   ('?', '.')],
#  [('Who', 'PRON'),
#   ('cried', 'VERB'),
#   ('most', 'ADJ'),
#   ('?', '.'),
#   ("''", '.')],
#  [('``', '.'), ('Ah', 'NOUN'), ('!', '.')],
#  [('poor', 'ADJ'), ('Miss', 'NOUN'), ('Taylor', 'NOUN'), ('!', '.')],
#  [("'T", 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('sad', 'ADJ'),
#   ('business', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('Poor', 'NOUN'),
#   ('Mr.', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Miss', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   (',', '.'),
#   ('if', 'ADP'),
#   ('you', 'PRON'),
#   ('please', 'VERB'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('I', 'PRON'),
#   ('can', 'VERB'),
#   ('not', 'ADV'),
#   ('possibly', 'ADV'),
#   ('say', 'VERB'),
#   ('`', '.'),
#   ('poor', 'ADJ'),
#   ('Miss', 'NOUN'),
#   ('Taylor', 'NOUN'),
#   ('.', '.'),
#   ("'", '.')],
#  [('I', 'PRON'),
#   ('have', 'VERB'),
#   ('a', 'DET'),
#   ('great', 'ADJ'),
#   ('regard', 'NOUN'),
#   ('for', 'ADP'),
#   ('you', 'PRON'),
#   ('and', 'CONJ'),
#   ('Emma', 'NOUN'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   ('when', 'ADV'),
#   ('it', 'PRON'),
#   ('comes', 'VERB'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('question', 'NOUN'),
#   ('of', 'ADP'),
#   ('dependence', 'NOUN'),
#   ('or', 'CONJ'),
#   ('independence', 'NOUN'),
#   ('!', '.'),
#   ('--', '.'),
#   ('At', 'ADP'),
#   ('any', 'DET'),
#   ('rate', 'NOUN'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('must', 'VERB'),
#   ('be', 'VERB'),
#   ('better', 'ADJ'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('only', 'ADV'),
#   ('one', 'NUM'),
#   ('to', 'PRT'),
#   ('please', 'VERB'),
#   ('than', 'ADP'),
#   ('two', 'NUM'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('Especially', 'ADV'),
#   ('when', 'ADV'),
#   ('_one_', 'NOUN'),
#   ('of', 'ADP'),
#   ('those', 'DET'),
#   ('two', 'NUM'),
#   ('is', 'VERB'),
#   ('such', 'DET'),
#   ('a', 'DET'),
#   ('fanciful', 'ADJ'),
#   (',', '.'),
#   ('troublesome', 'ADJ'),
#   ('creature', 'NOUN'),
#   ('!', '.'),
#   ("''", '.')],
#  [('said', 'VERB'), ('Emma', 'NOUN'), ('playfully', 'ADV'), ('.', '.')],
#  [('``', '.'),
#   ('That', 'DET'),
#   ('is', 'VERB'),
#   ('what', 'PRON'),
#   ('you', 'PRON'),
#   ('have', 'VERB'),
#   ('in', 'ADP'),
#   ('your', 'PRON'),
#   ('head', 'NOUN'),
#   (',', '.'),
#   ('I', 'PRON'),
#   ('know', 'VERB'),
#   ('--', '.'),
#   ('and', 'CONJ'),
#   ('what', 'PRON'),
#   ('you', 'PRON'),
#   ('would', 'VERB'),
#   ('certainly', 'ADV'),
#   ('say', 'VERB'),
#   ('if', 'ADP'),
#   ('my', 'PRON'),
#   ('father', 'NOUN'),
#   ('were', 'VERB'),
#   ('not', 'ADV'),
#   ('by', 'ADP'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('I', 'PRON'),
#   ('believe', 'VERB'),
#   ('it', 'PRON'),
#   ('is', 'VERB'),
#   ('very', 'ADV'),
#   ('true', 'ADJ'),
#   (',', '.'),
#   ('my', 'PRON'),
#   ('dear', 'ADJ'),
#   (',', '.'),
#   ('indeed', 'ADV'),
#   (',', '.'),
#   ("''", '.'),
#   ('said', 'VERB'),
#   ('Mr.', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   (',', '.'),
#   ('with', 'ADP'),
#   ('a', 'DET'),
#   ('sigh', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('I', 'PRON'),
#   ('am', 'VERB'),
#   ('afraid', 'ADJ'),
#   ('I', 'PRON'),
#   ('am', 'VERB'),
#   ('sometimes', 'ADV'),
#   ('very', 'ADV'),
#   ('fanciful', 'ADJ'),
#   ('and', 'CONJ'),
#   ('troublesome', 'ADJ'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('My', 'PRON'),
#   ('dearest', 'ADJ'),
#   ('papa', 'NOUN'),
#   ('!', '.')],
#  [('You', 'PRON'),
#   ('do', 'VERB'),
#   ('not', 'ADV'),
#   ('think', 'VERB'),
#   ('I', 'PRON'),
#   ('could', 'VERB'),
#   ('mean', 'VERB'),
#   ('_you_', 'NOUN'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('suppose', 'VERB'),
#   ('Mr.', 'NOUN'),
#   ('Knightley', 'NOUN'),
#   ('to', 'PRT'),
#   ('mean', 'VERB'),
#   ('_you_', 'NOUN'),
#   ('.', '.')],
#  [('What', 'PRON'),
#   ('a', 'DET'),
#   ('horrible', 'ADJ'),
#   ('idea', 'NOUN'),
#   ('!', '.')],
#  [('Oh', 'X'), ('no', 'DET'), ('!', '.')],
#  [('I', 'PRON'),
#   ('meant', 'VERB'),
#   ('only', 'ADV'),
#   ('myself', 'PRON'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Knightley', 'NOUN'),
#   ('loves', 'VERB'),
#   ('to', 'PRT'),
#   ('find', 'VERB'),
#   ('fault', 'NOUN'),
#   ('with', 'ADP'),
#   ('me', 'PRON'),
#   (',', '.'),
#   ('you', 'PRON'),
#   ('know', 'VERB'),
#   ('--', '.'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('joke', 'NOUN'),
#   ('--', '.'),
#   ('it', 'PRON'),
#   ('is', 'VERB'),
#   ('all', 'DET'),
#   ('a', 'DET'),
#   ('joke', 'NOUN'),
#   ('.', '.')],
#  [('We', 'PRON'),
#   ('always', 'ADV'),
#   ('say', 'VERB'),
#   ('what', 'PRON'),
#   ('we', 'PRON'),
#   ('like', 'VERB'),
#   ('to', 'PRT'),
#   ('one', 'NUM'),
#   ('another', 'DET'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Mr.', 'NOUN'),
#   ('Knightley', 'NOUN'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('fact', 'NOUN'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('one', 'NUM'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('few', 'ADJ'),
#   ('people', 'NOUN'),
#   ('who', 'PRON'),
#   ('could', 'VERB'),
#   ('see', 'VERB'),
#   ('faults', 'NOUN'),
#   ('in', 'ADP'),
#   ('Emma', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('only', 'ADJ'),
#   ('one', 'NOUN'),
#   ('who', 'PRON'),
#   ('ever', 'ADV'),
#   ('told', 'VERB'),
#   ('her', 'PRON'),
#   ('of', 'ADP'),
#   ('them', 'PRON'),
#   (':', '.'),
#   ('and', 'CONJ'),
#   ('though', 'ADP'),
#   ('this', 'DET'),
#   ('was', 'VERB'),
#   ('not', 'ADV'),
#   ('particularly', 'ADV'),
#   ('agreeable', 'ADJ'),
#   ('to', 'PRT'),
#   ('Emma', 'NOUN'),
#   ('herself', 'PRON'),
#   (',', '.'),
#   ('she', 'PRON'),
#   ('knew', 'VERB'),
#   ('it', 'PRON'),
#   ('would', 'VERB'),
#   ('be', 'VERB'),
#   ('so', 'ADV'),
#   ('much', 'ADJ'),
#   ('less', 'ADV'),
#   ('so', 'ADV'),
#   ('to', 'PRT'),
#   ('her', 'PRON'),
#   ('father', 'NOUN'),
#   (',', '.'),
#   ('that', 'ADP'),
#   ('she', 'PRON'),
#   ('would', 'VERB'),
#   ('not', 'ADV'),
#   ('have', 'VERB'),
#   ('him', 'PRON'),
#   ('really', 'ADV'),
# ...
#   ('admit', 'VERB'),
#   ('as', 'ADP'),
#   ('an', 'DET'),
#   ('acquaintance', 'NOUN'),
#   ('of', 'ADP'),
#   ('my', 'PRON'),
#   ('own', 'ADJ'),
#   ('!', '.')],
#  [('I', 'PRON'),
#   ('wonder', 'VERB'),
#   ('you', 'PRON'),
#   ('should', 'VERB'),
#   ('think', 'VERB'),
#   ('it', 'PRON'),
#   ('possible', 'ADJ'),
#   ('for', 'ADP'),
#   ('me', 'PRON'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('such', 'ADJ'),
#   ('feelings', 'NOUN'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('assure', 'VERB'),
#   ('you', 'PRON'),
#   ('mine', 'VERB'),
#   ('are', 'VERB'),
#   ('very', 'ADV'),
#   ('different', 'ADJ'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('must', 'VERB'),
#   ('think', 'VERB'),
#   ('your', 'PRON'),
#   ('statement', 'NOUN'),
#   ('by', 'ADP'),
#   ('no', 'DET'),
#   ('means', 'NOUN'),
#   ('fair', 'VERB'),
#   ('.', '.')],
#  [('You', 'PRON'),
#   ('are', 'VERB'),
#   ('not', 'ADV'),
#   ('just', 'ADV'),
#   ('to', 'PRT'),
#   ('Harriet', 'NOUN'),
#   ("'s", 'PRT'),
#   ('claims', 'NOUN'),
#   ('.', '.')],
#  [('They', 'PRON'),
#   ('would', 'VERB'),
#   ('be', 'VERB'),
#   ('estimated', 'VERB'),
#   ('very', 'ADV'),
#   ('differently', 'ADV'),
#   ('by', 'ADP'),
#   ('others', 'NOUN'),
#   ('as', 'ADV'),
#   ('well', 'ADV'),
#   ('as', 'ADP'),
#   ('myself', 'PRON'),
#   (';', '.'),
#   ('Mr.', 'NOUN'),
#   ('Martin', 'NOUN'),
#   ('may', 'VERB'),
#   ('be', 'VERB'),
#   ('the', 'DET'),
#   ('richest', 'ADJ'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('two', 'NUM'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('he', 'PRON'),
#   ('is', 'VERB'),
#   ('undoubtedly', 'ADV'),
#   ('her', 'PRON'),
#   ('inferior', 'ADJ'),
#   ('as', 'ADP'),
#   ('to', 'PRT'),
#   ('rank', 'VERB'),
#   ('in', 'ADP'),
#   ('society.', 'NOUN'),
#   ('--', '.'),
#   ('The', 'DET'),
#   ('sphere', 'NOUN'),
#   ('in', 'ADP'),
#   ('which', 'DET'),
#   ('she', 'PRON'),
#   ('moves', 'VERB'),
#   ('is', 'VERB'),
#   ('much', 'ADV'),
#   ('above', 'ADP'),
#   ('his.', 'NOUN'),
#   ('--', '.'),
#   ('It', 'PRON'),
#   ('would', 'VERB'),
#   ('be', 'VERB'),
#   ('a', 'DET'),
#   ('degradation', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('A', 'DET'),
#   ('degradation', 'NOUN'),
#   ('to', 'PRT'),
#   ('illegitimacy', 'NOUN'),
#   ('and', 'CONJ'),
#   ('ignorance', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('married', 'VERB'),
#   ('to', 'PRT'),
#   ('a', 'DET'),
#   ('respectable', 'ADJ'),
#   (',', '.'),
#   ('intelligent', 'ADJ'),
#   ('gentleman-farmer', 'NOUN'),
#   ('!', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('As', 'ADP'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('circumstances', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('birth', 'NOUN'),
#   (',', '.'),
#   ('though', 'ADV'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('legal', 'ADJ'),
#   ('sense', 'NOUN'),
#   ('she', 'PRON'),
#   ('may', 'VERB'),
#   ('be', 'VERB'),
#   ('called', 'VERB'),
#   ('Nobody', 'NOUN'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('will', 'VERB'),
#   ('not', 'ADV'),
#   ('hold', 'VERB'),
#   ('in', 'ADP'),
#   ('common', 'ADJ'),
#   ('sense', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('is', 'VERB'),
#   ('not', 'ADV'),
#   ('to', 'PRT'),
#   ('pay', 'VERB'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('offence', 'NOUN'),
#   ('of', 'ADP'),
#   ('others', 'NOUN'),
#   (',', '.'),
#   ('by', 'ADP'),
#   ('being', 'VERB'),
#   ('held', 'VERB'),
#   ('below', 'ADP'),
#   ('the', 'DET'),
#   ('level', 'NOUN'),
#   ('of', 'ADP'),
#   ('those', 'DET'),
#   ('with', 'ADP'),
#   ('whom', 'PRON'),
#   ('she', 'PRON'),
#   ('is', 'VERB'),
#   ('brought', 'ADJ'),
#   ('up.', 'ADV'),
#   ('--', '.'),
#   ('There', 'DET'),
#   ('can', 'VERB'),
#   ('scarcely', 'ADV'),
#   ('be', 'VERB'),
#   ('a', 'DET'),
#   ('doubt', 'NOUN'),
#   ('that', 'ADP'),
#   ('her', 'PRON'),
#   ('father', 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('gentleman', 'NOUN'),
#   ('--', '.'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('gentleman', 'NOUN'),
#   ('of', 'ADP'),
#   ('fortune.', 'NOUN'),
#   ('--', '.'),
#   ('Her', 'PRON'),
#   ('allowance', 'NOUN'),
#   ('is', 'VERB'),
#   ('very', 'ADV'),
#   ('liberal', 'ADJ'),
#   (';', '.'),
#   ('nothing', 'NOUN'),
#   ('has', 'VERB'),
#   ('ever', 'ADV'),
#   ('been', 'VERB'),
#   ('grudged', 'VERB'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('improvement', 'NOUN'),
#   ('or', 'CONJ'),
#   ('comfort.', 'NOUN'),
#   ('--', '.'),
#   ('That', 'ADP'),
#   ('she', 'PRON'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('gentleman', 'NOUN'),
#   ("'s", 'PRT'),
#   ('daughter', 'NOUN'),
#   (',', '.'),
#   ('is', 'VERB'),
#   ('indubitable', 'ADJ'),
#   ('to', 'PRT'),
#   ('me', 'PRON'),
#   (';', '.'),
#   ('that', 'ADP'),
#   ('she', 'PRON'),
#   ('associates', 'VERB'),
#   ('with', 'ADP'),
#   ('gentlemen', 'NOUN'),
#   ("'s", 'PRT'),
#   ('daughters', 'NOUN'),
#   (',', '.'),
#   ('no', 'DET'),
#   ('one', 'NOUN'),
#   (',', '.'),
#   ('I', 'PRON'),
#   ('apprehend', 'VERB'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('deny.', 'VERB'),
#   ('--', '.'),
#   ('She', 'PRON'),
#   ('is', 'VERB'),
#   ('superior', 'ADJ'),
#   ('to', 'PRT'),
#   ('Mr.', 'NOUN'),
#   ('Robert', 'NOUN'),
#   ('Martin', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('Whoever', 'PRON'),
#   ('might', 'VERB'),
#   ('be', 'VERB'),
#   ('her', 'PRON'),
#   ('parents', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('said', 'VERB'),
#   ('Mr.', 'NOUN'),
#   ('Knightley', 'NOUN'),
#   (',', '.'),
#   ('``', '.'),
#   ('whoever', 'NOUN'),
#   ('may', 'VERB'),
#   ('have', 'VERB'),
#   ('had', 'VERB'),
#   ('the', 'DET'),
#   ('charge', 'NOUN'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('does', 'VERB'),
#   ('not', 'ADV'),
#   ('appear', 'VERB'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('been', 'VERB'),
#   ('any', 'DET'),
#   ('part', 'NOUN'),
#   ('of', 'ADP'),
#   ('their', 'PRON'),
#   ('plan', 'NOUN'),
#   ('to', 'PRT'),
#   ('introduce', 'VERB'),
#   ('her', 'PRON'),
#   ('into', 'ADP'),
#   ('what', 'PRON'),
#   ('you', 'PRON'),
#   ('would', 'VERB'),
#   ('call', 'VERB'),
#   ('good', 'ADJ'),
#   ('society', 'NOUN'),
#   ('.', '.')],
#  [('After', 'ADP'),
#   ('receiving', 'VERB'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('indifferent', 'ADJ'),
#   ('education', 'NOUN'),
#   ('she', 'PRON'),
#   ('is', 'VERB'),
#   ('left', 'VERB'),
#   ('in', 'ADP'),
#   ('Mrs.', 'NOUN'),
#   ('Goddard', 'NOUN'),
#   ("'s", 'PRT'),
#   ('hands', 'NOUN'),
#   ('to', 'PRT'),
#   ('shift', 'VERB'),
#   ('as', 'ADP'),
#   ('she', 'PRON'),
#   ('can', 'VERB'),
#   (';', '.'),
#   ('--', '.'),
#   ('to', 'PRT'),
#   ('move', 'VERB'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('short', 'ADJ'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('Mrs.', 'NOUN'),
#   ('Goddard', 'NOUN'),
#   ("'s", 'PRT'),
#   ('line', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('Mrs.', 'NOUN'),
#   ('Goddard', 'NOUN'),
#   ("'s", 'PRT'),
#   ('acquaintance', 'NOUN'),
#   ('.', '.')],
#  [('Her', 'PRON'),
#   ('friends', 'NOUN'),
#   ('evidently', 'ADV'),
#   ('thought', 'VERB'),
#   ('this', 'DET'),
#   ('good', 'ADJ'),
#   ('enough', 'ADV'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('it', 'PRON'),
#   ('_was_', 'ADV'),
#   ('good', 'ADJ'),
#   ('enough', 'ADV'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('desired', 'VERB'),
#   ('nothing', 'NOUN'),
#   ('better', 'ADV'),
#   ('herself', 'PRON'),
#   ('.', '.')],
#  [('Till', 'NOUN'),
#   ('you', 'PRON'),
#   ('chose', 'VERB'),
#   ('to', 'PRT'),
#   ('turn', 'VERB'),
#   ('her', 'PRON'),
#   ('into', 'ADP'),
#   ('a', 'DET'),
#   ('friend', 'NOUN'),
#   (',', '.'),
#   ('her', 'PRON'),
#   ('mind', 'NOUN'),
#   ('had', 'VERB'),
#   ('no', 'DET'),
#   ('distaste', 'NOUN'),
#   ('for', 'ADP'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('set', 'NOUN'),
#   (',', '.'),
#   ('nor', 'CONJ'),
#   ('any', 'DET'),
#   ('ambition', 'NOUN'),
#   ('beyond', 'ADP'),
#   ('it', 'PRON'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('was', 'VERB'),
#   ('as', 'ADV'),
#   ('happy', 'ADJ'),
#   ('as', 'ADP'),
#   ('possible', 'ADJ'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('Martins', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('summer', 'NOUN'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('had', 'VERB'),
#   ('no', 'DET'),
#   ('sense', 'NOUN'),
#   ('of', 'ADP'),
#   ('superiority', 'NOUN'),
#   ('then', 'ADV'),
#   ('.', '.')],
#  [('If', 'ADP'),
#   ('she', 'PRON'),
#   ('has', 'VERB'),
#   ('it', 'PRON'),
#   ('now', 'ADV'),
#   (',', '.'),
#   ('you', 'PRON'),
#   ('have', 'VERB'),
#   ('given', 'VERB'),
#   ('it', 'PRON'),
#   ('.', '.')],
#  [('You', 'PRON'),
#   ('have', 'VERB'),
#   ('been', 'VERB'),
#   ('no', 'DET'),
#   ('friend', 'NOUN'),
#   ('to', 'PRT'),
#   ('Harriet', 'NOUN'),
#   ('Smith', 'NOUN'),
#   (',', '.'),
#   ('Emma', 'NOUN'),
#   ('.', '.')],
#  [('Robert', 'NOUN'),
#   ('Martin', 'NOUN'),
#   ('would', 'VERB'),
#   ('never', 'ADV'),
#   ('have', 'VERB'),
#   ('proceeded', 'VERB'),
#   ('so', 'ADV'),
#   ('far', 'ADV'),
#   (',', '.'),
#   ('if', 'ADP'),
#   ('he', 'PRON'),
#   ('had', 'VERB'),
#   ('not', 'ADV'),
#   ('felt', 'VERB'),
#   ('persuaded', 'VERB'),
#   ('of', 'ADP'),
#   ('her', 'PRON'),
#   ('not', 'ADV'),
#   ('being', 'VERB'),
#   ('disinclined', 'VERB'),
#   ('to', 'PRT'),
#   ('him', 'PRON'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('know', 'VERB'),
#   ('him', 'PRON'),
#   ('well', 'ADV'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('has', 'VERB'),
#   ('too', 'ADV'),
#   ('much', 'ADJ'),
#   ('real', 'ADJ'),
#   ('feeling', 'NOUN'),
#   ('to', 'PRT'),
#   ('address', 'VERB'),
#   ('any', 'DET'),
#   ('woman', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('haphazard', 'NOUN'),
#   ('of', 'ADP'),
#   ('selfish', 'ADJ'),
#   ('passion', 'NOUN'),
#   ('.', '.')],
#  [('And', 'CONJ'),
#   ('as', 'ADP'),
#   ('to', 'PRT'),
#   ('conceit', 'VERB'),
#   (',', '.'),
#   ('he', 'PRON'),
#   ('is', 'VERB'),
#   ('the', 'DET'),
#   ('farthest', 'ADJ'),
#   ('from', 'ADP'),
#   ('it', 'PRON'),
#   ('of', 'ADP'),
#   ('any', 'DET'),
#   ('man', 'NOUN'),
#   ('I', 'PRON'),
#   ('know', 'VERB'),
#   ('.', '.')],
#  [('Depend', 'NOUN'),
#   ('upon', 'ADP'),
#   ('it', 'PRON'),
#   ('he', 'PRON'),
#   ('had', 'VERB'),
#   ('encouragement', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('It', 'PRON'),
#   ('was', 'VERB'),
#   ('most', 'ADV'),
#   ('convenient', 'ADJ'),
#   ('to', 'PRT'),
#   ('Emma', 'NOUN'),
#   ('not', 'ADV'),
#   ('to', 'PRT'),
#   ('make', 'VERB'),
#   ('a', 'DET'),
#   ('direct', 'ADJ'),
#   ('reply', 'NOUN'),
#   ('to', 'PRT'),
#   ('this', 'DET'),
#   ('assertion', 'NOUN'),
#   (';', '.'),
#   ('she', 'PRON'),
#   ('chose', 'VERB'),
#   ('rather', 'ADV'),
#   ('to', 'PRT'),
#   ('take', 'VERB'),
#   ('up', 'PRT'),
#   ('her', 'PRON'),
#   ('own', 'ADJ'),
#   ('line', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('subject', 'NOUN'),
#   ('again', 'ADV'),
#   ('.', '.')],
#  [('``', '.'),
#   ('You', 'PRON'),
#   ('are', 'VERB'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('warm', 'ADJ'),
#   ('friend', 'NOUN'),
#   ('to', 'PRT'),
#   ('Mr.', 'NOUN'),
#   ('Martin', 'NOUN'),
#   (';', '.'),
#   ('but', 'CONJ'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('I', 'PRON'),
#   ('said', 'VERB'),
#   ('before', 'ADP'),
#   (',', '.'),
#   ('are', 'VERB'),
#   ('unjust', 'ADJ'),
#   ('to', 'PRT'),
#   ('Harriet', 'NOUN'),
#   ('.', '.')],
#  [('Harriet', 'NOUN'),
#   ("'s", 'PRT'),
#   ('claims', 'NOUN'),
#   ('to', 'PRT'),
#   ('marry', 'VERB'),
#   ('well', 'ADV'),
#   ('are', 'VERB'),
#   ('not', 'ADV'),
#   ('so', 'ADV'),
#   ('contemptible', 'ADJ'),
#   ('as', 'ADP'),
#   ('you', 'PRON'),
#   ('represent', 'VERB'),
#   ('them', 'PRON'),
#   ('.', '.')],
#  [('She', 'PRON'),
#   ('is', 'VERB'),
#   ('not', 'ADV'),
#   ('a', 'DET'),
#   ('clever', 'NOUN'),
#   ('girl', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('she', 'PRON'),
#   ('has', 'VERB'),
#   ('better', 'ADJ'),
#   ('sense', 'NOUN'),
#   ('than', 'ADP'),
#   ('you', 'PRON'),
#   ('are', 'VERB'),
#   ('aware', 'ADJ'),
#   ('of', 'ADP'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('does', 'VERB'),
#   ('not', 'ADV'),
#   ('deserve', 'VERB'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('her', 'PRON'),
#   ('understanding', 'ADJ'),
#   ('spoken', 'NOUN'),
#   ('of', 'ADP'),
#   ('so', 'ADV'),
#   ('slightingly', 'ADV'),
#   ('.', '.')],
#  [('Waiving', 'VERB'),
#   ('that', 'DET'),
#   ('point', 'NOUN'),
#   (',', '.'),
#   ('however', 'ADV'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('supposing', 'VERB'),
#   ('her', 'PRON'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('you', 'PRON'),
#   ('describe', 'VERB'),
#   ('her', 'PRON'),
#   (',', '.'),
#   ('only', 'ADV'),
#   ('pretty', 'ADV'),
#   ('and', 'CONJ'),
#   ('good-natured', 'ADJ'),
#   (',', '.'),
#   ('let', 'VERB'),
#   ('me', 'PRON'),
#   ('tell', 'VERB'),
#   ('you', 'PRON'),
#   (',', '.'),
#   ('that', 'ADP'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('degree', 'NOUN'),
#   ('she', 'PRON'),
#   ('possesses', 'VERB'),
#   ('them', 'PRON'),
#   (',', '.'),
#   ('they', 'PRON'),
#   ('are', 'VERB'),
#   ('not', 'ADV'),
#   ('trivial', 'ADJ'),
#   ('recommendations', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('world', 'NOUN'),
#   ('in', 'ADP'),
#   ('general', 'ADJ'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('she', 'PRON'),
#   ('is', 'VERB'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('fact', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('beautiful', 'ADJ'),
#   ('girl', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('must', 'VERB'),
#   ('be', 'VERB'),
#   ('thought', 'VERB'),
#   ('so', 'ADV'),
#   ('by', 'ADP'),
#   ('ninety-nine', 'ADJ'),
#   ('people', 'NOUN'),
#   ('out', 'ADP'),
#   ('of', 'ADP'),
#   ('an', 'DET'),
#   ('hundred', 'VERB'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('till', 'VERB'),
#   ('it', 'PRON'),
#   ('appears', 'VERB'),
#   ('that', 'ADP'),
#   ('men', 'NOUN'),
#   ('are', 'VERB'),
#   ('much', 'ADV'),
#   ('more', 'ADV'),
#   ('philosophic', 'ADJ'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('subject', 'NOUN'),
#   ('of', 'ADP'),
#   ('beauty', 'NOUN'),
#   ('than', 'ADP'),
#   ('they', 'PRON'),
#   ('are', 'VERB'),
#   ('generally', 'ADV'),
#   ('supposed', 'VERB'),
#   (';', '.'),
#   ('till', 'NOUN'),
#   ('they', 'PRON'),
#   ('do', 'VERB'),
#   ('fall', 'VERB'),
#   ('in', 'ADP'),
#   ('love', 'NOUN'),
#   ('with', 'ADP'),
#   ('well-informed', 'ADJ'),
#   ('minds', 'NOUN'),
#   ('instead', 'ADV'),
#   ('of', 'ADP'),
#   ('handsome', 'ADJ'),
#   ('faces', 'VERB'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('girl', 'NOUN'),
#   (',', '.'),
#   ('with', 'ADP'),
#   ('such', 'ADJ'),
#   ('loveliness', 'NOUN'),
#   ('as', 'ADP'),
#   ('Harriet', 'NOUN'),
#   (',', '.'),
#   ('has', 'VERB'),
#   ('a', 'DET'),
#   ('certainty', 'NOUN'),
#   ('of', 'ADP'),
#   ('being', 'VERB'),
#   ('admired', 'VERB'),
#   ('and', 'CONJ'),
#   ('sought', 'VERB'),
#   ('after', 'ADP'),
#   (',', '.'),
#   ('of', 'ADP'),
#   ('having', 'VERB'),
#   ('the', 'DET'),
#   ('power', 'NOUN'),
#   ('of', 'ADP'),
#   ('chusing', 'VERB'),
#   ('from', 'ADP'),
#   ('among', 'ADP'),
#   ('many', 'ADJ'),
#   (',', '.'),
#   ('consequently', 'ADV'),
#   ('a', 'DET'),
#   ('claim', 'NOUN'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('nice', 'ADJ'),
#   ('.', '.')],
#  [('Her', 'PRON'),
#   ('good-nature', 'NOUN'),
#   (',', '.'),
#   ('too', 'ADV'),
#   (',', '.'),
#   ('is', 'VERB'),
#   ('not', 'ADV'),
#   ('so', 'ADV'),
#   ('very', 'ADV'),
#   ('slight', 'ADJ'),
#   ('a', 'DET'),
#   ('claim', 'NOUN'),
#   (',', '.'),
#   ('comprehending', 'VERB'),
#   (',', '.'),
#   ('as', 'ADP'),
#   ('it', 'PRON'),
#   ('does', 'VERB'),
#   (',', '.'),
#   ('real', 'ADJ'),
#   (',', '.'),
#   ('thorough', 'ADJ'),
#   ('sweetness', 'NOUN'),
#   ('of', 'ADP'),
#   ('temper', 'NOUN'),
#   ('and', 'CONJ'),
#   ('manner', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('very', 'ADV'),
#   ('humble', 'ADJ'),
#   ('opinion', 'NOUN'),
#   ('of', 'ADP'),
#   ('herself', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('great', 'ADJ'),
#   ('readiness', 'NOUN'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('pleased', 'VERB'),
#   ('with', 'ADP'),
#   ('other', 'ADJ'),
#   ('people', 'NOUN'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('am', 'VERB'),
#   ('very', 'ADV'),
#   ('much', 'ADV'),
#   ('mistaken', 'VERB'),
#   ('if', 'ADP'),
#   ('your', 'PRON'),
#   ('sex', 'NOUN'),
#   ('in', 'ADP'),
#   ('general', 'ADJ'),
#   ('would', 'VERB'),
#   ('not', 'ADV'),
#   ('think', 'VERB'),
#   ('such', 'ADJ'),
#   ('beauty', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('such', 'ADJ'),
#   ('temper', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('highest', 'ADJ'),
#   ('claims', 'NOUN'),
#   ('a', 'DET'),
#   ('woman', 'NOUN'),
#   ('could', 'VERB'),
#   ('possess', 'VERB'),
#   ('.', '.'),
#   ("''", '.')],
#  [('``', '.'),
#   ('Upon', 'ADP'),
#   ('my', 'PRON'),
#   ('word', 'NOUN'),
#   (',', '.'),
#   ('Emma', 'NOUN'),
#   (',', '.'),
#   ('to', 'PRT'),
#   ('hear', 'VERB'),
#   ('you', 'PRON'),
#   ('abusing', 'VERB'),
#   ('the', 'DET'),
#   ('reason', 'NOUN'),
#   ('you', 'PRON'),
#   ('have', 'VERB'),
#   (',', '.'),
#   ('is', 'VERB'),
#   ('almost', 'ADV'),
#   ('enough', 'ADJ'),
#   ('to', 'PRT'),
#   ('make', 'VERB'),
#   ('me', 'PRON'),
#   ('think', 'VERB'),
#   ('so', 'ADV'),
#   ('too', 'ADV'),
#   ('.', '.')],
#  ...]

# %% [markdown]
# ### Exercise 2.3
# *What is the number of distinct stems in Austen's "Emma"?*

# %%
# put your code here
emma = nltk.corpus.gutenberg.words('austen-emma.txt')
len(emma)
# Out:
# 192427

# %%
stemmer = nltk.PorterStemmer()
stems_list = set()
for sentence in emma_sent:
    for w in word_tokenize(sentence):
        stems_list.add(stemmer.stem(w))

print(len(stems_list))
# Out:
# 5335

# %% [markdown]
# ### (Optional) Exercise 2.4
# *What is the most ambiguous stem in Austen's "Emma"? (meaning, which stem in Austen's "Emma" is realised in the largest number of distinct tokens?)*

# %%
# put your code here

# %% [markdown]
# # 3. Post-practical questionnaire
#
# Please complete the week 7 post-practical questionnaire on iLearn.
